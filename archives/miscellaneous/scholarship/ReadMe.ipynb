# %% [markdown]
# # Paying multiple scholarships from multiple Marlowe contracts
#
#
# **Executive Summary**
#
# This example demonstrates a multisig address simultaneously creating 100 contracts that escrow scholarship funds. Each of those contracts will pay the scholarship funds to a specific address if an oracle attests that they have earned the scholarship; otherwise the funds are returned to the multisig address. This contract is secure against misbehavior of the oracle in that the oracle cannot steal funds: the worst it can do is mis-award scholarships. The list of scholars' addresses must be defined before the contracts are created and, for security, the holders of the multisig keys must review the transaction they sign to ensure that it does indeed create escrowed scholarships for that list of addresses. Conceptually, each contract can be represented as the Blockly diagram below, where `Scholar` is the address of a particular scholar.
#
# ![Marlowe contract for a scholarship](contract-conceptual.png)
#
# Thus, funds flow in the following manner.
#
# ![Flow of transactions](flow.png)
#
# A [video demonstration of this example](https://youtu.be/H4PdCJvt7fQ) is available.

# %% [markdown]
# ## Constants
#
# It is convenient to define serveral constants.

# %%
ADA=1000000

# %%
SECOND=1000
MINUTE=$((60 * SECOND))
HOUR=$((60 * MINUTE))

# %% [markdown]
# ## Temporary folders

# %%
mkdir -p contracts states marlowes txs

# %% [markdown]
# ## Network
#
# Use the preproduction network.

# %%
export CARDANO_NODE_SOCKET_PATH=/extra/iohk/networks/preprod/node.socket
export CARDANO_TESTNET_MAGIC=1

# %% [markdown]
# ## Parties to the contracts
#
# Set the signing keys and addresses for parties to the contracts.

# %% [markdown]
# ### Verifier
#
# The *Verifier* authorizes payment of the scholarships.

# %%
VERIFIER_NAME=m.herbert
VERIFIER_SKEY=../keys/$VERIFIER_NAME.skey
VERIFIER_ADDR=$(cat ../keys/$VERIFIER_NAME.testnet.address)
echo "$VERIFIER_NAME @ $VERIFIER_ADDR"
# Out:
# m.herbert @ addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw

# %% [markdown]
# Tidy the UTxOs at the verifier's address.

# %%
/extra/iohk/bin/marlowe-cli util clean \
  --change-address "$VERIFIER_ADDR" \
  --required-signer "$VERIFIER_SKEY" \
  --out-file /dev/null \
  --submit 600
# Out:
# TxId "79e8931f15eaf91ae625f8b08a95d003cf8e8fcbfdcc10d3583f664a06957b80"

# %% [markdown]
# View the funds at the verifier's address.

# %%
cardano-cli query utxo \
  --testnet-magic "$CARDANO_TESTNET_MAGIC" \
  --address "$VERIFIER_ADDR"
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 79e8931f15eaf91ae625f8b08a95d003cf8e8fcbfdcc10d3583f664a06957b80     0        252182765 lovelace + TxOutDatumNone
# 79e8931f15eaf91ae625f8b08a95d003cf8e8fcbfdcc10d3583f664a06957b80     1        2000000 lovelace + 2 8bb3b343d8e404472337966a722150048c768d0a92a9813596c5338d.6d2e68657262657274 + TxOutDatumNone

# %% [markdown]
# ### Scholars
#
# Normally, the list of addresses for the *Scholars* would be provided. Here, for convenience, we justderive each scholar's address from the same root private key.

# %%
ROOT_PRV=../keys/william-shakespeare.root.prv

# %% [markdown]
# Also for convenience, the scholars will share the same stake key.

# %%
cardano-wallet key child 1852H/1815H/0H/2/0 < $ROOT_PRV \
| cardano-cli key convert-cardano-address-key --shelley-stake-key --signing-key-file /dev/stdin --out-file /dev/stdout \
| cardano-cli key verification-key --signing-key-file /dev/stdin --verification-key-file /dev/stdout \
| cardano-cli key non-extended-key --extended-verification-key-file /dev/stdin --verification-key-file ../keys/william-shakespeare.stake.vkey
STAKE_ADDR=$(cardano-cli stake-address build --testnet-magic $CARDANO_TESTNET_MAGIC --stake-verification-key-file ../keys/william-shakespeare.stake.vkey)
echo "Stake address = $STAKE_ADDR"
# Out:
# Stake address = stake_test1urplvp2a7dythh6yxutd0qlzzkncr3gy5ftvxj02d3etafqjugc5h

# %% [markdown]
# Set the number of scholars.

# %%
NUMBER_OF_SCHOLARS=100

# %% [markdown]
# Compute the addresses of the scholars.

# %%
for j in $(seq 1 $NUMBER_OF_SCHOLARS)
do
  SCHOLAR_SKEY[$j]=../keys/scholar-$j.skey
  SCHOLAR_ADDR[$j]=$(
  cardano-wallet key child 1852H/1815H/0H/0/$j < $ROOT_PRV \
  | cardano-cli key convert-cardano-address-key --shelley-payment-key --signing-key-file /dev/stdin --out-file ${SCHOLAR_SKEY[$j]}
  cardano-cli key verification-key --signing-key-file ${SCHOLAR_SKEY[$j]} --verification-key-file /dev/stdout \
  | cardano-cli address build --testnet-magic $CARDANO_TESTNET_MAGIC --payment-verification-key-file /dev/stdin --stake-verification-key-file ../keys/william-shakespeare.stake.vkey \
  )
  echo "Scholar $j = 1852H/1815H/0H/0/$((1 + j)) = ${SCHOLAR_ADDR[$j]}"
done
# Out:
# Scholar 1 = 1852H/1815H/0H/0/2 = addr_test1qzenwj7elwatk3mmc368mwnv067fqnuk3x7u4nqw5dezg8wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqf6k36p
# Scholar 2 = 1852H/1815H/0H/0/3 = addr_test1qraxynufcduk7ak7nke2jm6pnc32vn7wsmm7ml30cutfgg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq77wfgp
# Scholar 3 = 1852H/1815H/0H/0/4 = addr_test1qzlwepx5u26a8w94kfrkfem6njlam22emyhjscu0lxqrce7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5jnrn3
# Scholar 4 = 1852H/1815H/0H/0/5 = addr_test1qqjrjfslev50d5jn6qdeztxsqvuaaefq6e4hu55n59grjj7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwhulyr
# Scholar 5 = 1852H/1815H/0H/0/6 = addr_test1qqxrzfv0v8l0lahyc5qsgpug66dafp8njl278g0pter7e3xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqcjuuw0
# Scholar 6 = 1852H/1815H/0H/0/7 = addr_test1qqqfzyuqkvrr7ajgk887sqac8lgzatc6el9uxke4x5g5dg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkmrpwu
# Scholar 7 = 1852H/1815H/0H/0/8 = addr_test1qp77epd4gy5hrt8pnh6h73se4durwrrkes3u0vj6tycwsq7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7kyfpt
# Scholar 8 = 1852H/1815H/0H/0/9 = addr_test1qqau5f983jd4p5jxx7uxek4axcuuyqgc3q20d9el33ydg4kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqvdshe7
# Scholar 9 = 1852H/1815H/0H/0/10 = addr_test1qry8r8w64h8t6luv4gcvny3snjzmytvrge5euj0ydqchh3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq8f955r
# Scholar 10 = 1852H/1815H/0H/0/11 = addr_test1qzf7zduewu3zjw586mv8r0cxtctwsccsydk7d2hxdcad2s7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jql02nhc
# Scholar 11 = 1852H/1815H/0H/0/12 = addr_test1qz5acr3p66e5jzts96jhlgh8nhuurydw5364xs9u2kdwlg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqrudtl4
# Scholar 12 = 1852H/1815H/0H/0/13 = addr_test1qp85hggjkyjzq32m9hk6yfwp8xdz0j6kq7g8j4f2akfl9ckr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq8xh40m
# Scholar 13 = 1852H/1815H/0H/0/14 = addr_test1qp5uceg0yhxgra7a8emm0d4k8v6qqm4g3tg65ywtqkhcaawr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqyctq4d
# Scholar 14 = 1852H/1815H/0H/0/15 = addr_test1qqs5whf8xtzdn9myltr7svnug89g5hr48u4zl3lugcrxr67r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqruqfn5
# Scholar 15 = 1852H/1815H/0H/0/16 = addr_test1qrj49qkfmr72mgmt3lsktde0havnv72yp9qsvsq6365dyp7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqnpl2rv
# Scholar 16 = 1852H/1815H/0H/0/17 = addr_test1qqgdvj84rncnlm754fwttn3py73hp85454tzxzll9sk98rkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqj6jhze
# Scholar 17 = 1852H/1815H/0H/0/18 = addr_test1qrjk5w2t35r7qpuc0mlxcuazvta0e4d8wsn7mq6wpq4fa2kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq0zqdga
# Scholar 18 = 1852H/1815H/0H/0/19 = addr_test1qrnartu48wqykfavssdsgsz6vvgqxgv9s43tgpzrauh6ugwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwu7lzs
# Scholar 19 = 1852H/1815H/0H/0/20 = addr_test1qpftg7deaxswzauukv2hqsegtrr4q680ayd6683k3rg8gkkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqv7jm9y
# Scholar 20 = 1852H/1815H/0H/0/21 = addr_test1qzx9gsxhj09ne3vz73jzg25calq9skl3fxwedxdfu6y7gdkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqvt6lj0
# Scholar 21 = 1852H/1815H/0H/0/22 = addr_test1qzlv9amdympgu47t6tu4ec5lz6uhu2qnq8ulwk9caasm7f7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqulv0pl
# Scholar 22 = 1852H/1815H/0H/0/23 = addr_test1qq6nzgz24yj8u2fy45psnrn4emdwh7scjh29j43z3pv5rckr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7h6t4e
# Scholar 23 = 1852H/1815H/0H/0/24 = addr_test1qrhpp4kv5vxpr0kqerx5stkyfqghf8pjltmcucdscuzvg57r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkeka27
# Scholar 24 = 1852H/1815H/0H/0/25 = addr_test1qzlweggfq6ara5tytufktkcyjv7j29garuhyufz5ryzxnqwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2lh7qe
# Scholar 25 = 1852H/1815H/0H/0/26 = addr_test1qp0t92r5ep5suj08mpk8mcy7phfuq3607wmksp8z407z6kkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2xwugk
# Scholar 26 = 1852H/1815H/0H/0/27 = addr_test1qzhdl8anw4ssr75uguffuem6227ay9rh3wp855pq6scjc5xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqe2smw4
# Scholar 27 = 1852H/1815H/0H/0/28 = addr_test1qzg57krydk30ydzd39ltjvs9wqd3jsf2er5e8asr4faycfxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqmzupaz
# Scholar 28 = 1852H/1815H/0H/0/29 = addr_test1qpcfw8xjj9vk7889m45mpw4lnmt5ackful200xxp6q3r98wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqez5l32
# Scholar 29 = 1852H/1815H/0H/0/30 = addr_test1qzyp0dv2hq77jvhk4kh3y45g63tfx759ufwcsu892ukvegkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqqun809
# Scholar 30 = 1852H/1815H/0H/0/31 = addr_test1qp5g75sm5esea8alu07e8c5k63ywns5tq74lvh8ursr48s7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjpx5tl
# Scholar 31 = 1852H/1815H/0H/0/32 = addr_test1qpy8fx7kasu376v3c9pskxckj5stk6ejy2nswnq0requ45kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqm0r9l6
# Scholar 32 = 1852H/1815H/0H/0/33 = addr_test1qpazh38gxxnt6yxafz8vf0ryrdc8n8tyc4xlv97c7f8qqfwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5zqhdp
# Scholar 33 = 1852H/1815H/0H/0/34 = addr_test1qpf5pakhjntq8fyxmtc6gv6wf8c5dz8k9dv3nk06dk423awr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq4kdl8u
# Scholar 34 = 1852H/1815H/0H/0/35 = addr_test1qpfhfug63l0ys2a2vm0wldmxjjlaqgk4u280m4pmk6f8cp7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqpdfphd
# Scholar 35 = 1852H/1815H/0H/0/36 = addr_test1qrpjhy8rnc9h50vusd4tsh2nfep9w6n7qutdzs2gpjqfh6xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqffy4uy
# Scholar 36 = 1852H/1815H/0H/0/37 = addr_test1qpdsderx7fdh3vx42sx8j4kjcxj3k2d58fgsd5ptya5ulywr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2ruk85
# Scholar 37 = 1852H/1815H/0H/0/38 = addr_test1qq4fsl04nuu03njzwh6n89uhgu63x9ypjeg84q4pdzvqttkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7ywduq
# Scholar 38 = 1852H/1815H/0H/0/39 = addr_test1qq5gmdhh65mxm3pje855vwsgfrj90wye43grnq3zzu9ug0wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jql9ku83
# Scholar 39 = 1852H/1815H/0H/0/40 = addr_test1qpummduqr4zq3vkxmjxqwvatrfm2wgeefn23p3y5us2rxpkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqntpetu
# Scholar 40 = 1852H/1815H/0H/0/41 = addr_test1qzwxx7va22maycmt0wfhzw4q6zy885658swh3yzvxq5860wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqez9c58
# Scholar 41 = 1852H/1815H/0H/0/42 = addr_test1qp7sp0w8ljvmau95rsscmg8zegmem4cya6hmyr276hr3c7kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqpm58rl
# Scholar 42 = 1852H/1815H/0H/0/43 = addr_test1qzwsqegmud7dcr8prnslmhh97war84dh4z9t7v5xgh8jh2xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqnq9x0k
# Scholar 43 = 1852H/1815H/0H/0/44 = addr_test1qz2nmcnwdrxrksk4fvfw9x3myrxndcwhqwkxe5f9lw2azyxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqtxn85r
# Scholar 44 = 1852H/1815H/0H/0/45 = addr_test1qpek6vrkj00g5vcvzxs74xrzt6clfwc964puu2k32f76hk7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqv26z8x
# Scholar 45 = 1852H/1815H/0H/0/46 = addr_test1qq8ses7vgfl9rmj0tjtzvt3r7twpku4cv3c7naxtltlwwqwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq34fkvd
# Scholar 46 = 1852H/1815H/0H/0/47 = addr_test1qpggkalsqjuc4t2pj7arzf66he2u7eultqpq3vc7xexunl7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqw03sf5
# Scholar 47 = 1852H/1815H/0H/0/48 = addr_test1qzpjuk3pjy47s5pt7danm0d2765e9w8ana9jms38xd0ghfxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqs6uqev
# Scholar 48 = 1852H/1815H/0H/0/49 = addr_test1qpevx0exxesd4yz5xl0zsuf5rnlg30gkm9l6xtph3ajed2wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqpd5pd8
# Scholar 49 = 1852H/1815H/0H/0/50 = addr_test1qqvtgtjgsqcr96wv0xw4cgpjz0qatr7r0g3hfk2tu2xvlhwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq54hatp
# Scholar 50 = 1852H/1815H/0H/0/51 = addr_test1qq2hewgkma04wx6udewv6heh3rdvw2agp3gtwa96cz9k4kkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqa6sxxs
# Scholar 51 = 1852H/1815H/0H/0/52 = addr_test1qr5zm006w3nd3etsmttwyk298pu65jwwuk4wc8s2zhsv59kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq9zk0w9
# Scholar 52 = 1852H/1815H/0H/0/53 = addr_test1qp9p3fh0jh49ypts970970zve2e7lwx3x2wqdgurmumwz5xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkrrxts
# Scholar 53 = 1852H/1815H/0H/0/54 = addr_test1qp4rwv6whephyqm8l4esavujwnfdhenqqnxwdvtdp7zampxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5q7hz7
# Scholar 54 = 1852H/1815H/0H/0/55 = addr_test1qze89as8wq67p63gpcj0ycg8rgrs4d5gfykkgq463py404xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwy6dex
# Scholar 55 = 1852H/1815H/0H/0/56 = addr_test1qza96yahn4m8awmzpqwk6d07z6lxfyphqcwvar6e23pj27xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq6yduup
# Scholar 56 = 1852H/1815H/0H/0/57 = addr_test1qp37f8ysp9ez3wmfnr5vh3hl4z2670fvs2exln2w0zgs3cxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqv49m2k
# Scholar 57 = 1852H/1815H/0H/0/58 = addr_test1qrsgyj9wcl9jjqkl0nm8rf28m4gs54grycup9a5krezaqcxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqfjkpp8
# Scholar 58 = 1852H/1815H/0H/0/59 = addr_test1qzn4wvyj6mvdyaxnj8yhpujxa9m6amp3t5gaevw8etmd9a7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqw7gjta
# Scholar 59 = 1852H/1815H/0H/0/60 = addr_test1qz3gznr4hw3jg3t4llp0pezdrwqsjz5ngjx7vsq9pklqwwwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq3j4820
# Scholar 60 = 1852H/1815H/0H/0/61 = addr_test1qq588p04pqus2358226a0fjcvcxq22u4zc0edal0fw3m77wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqp9h4tq
# Scholar 61 = 1852H/1815H/0H/0/62 = addr_test1qq84w78q9lvfp7jart6nl2qckwzmuww37q2yja8cpqp5607r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq8z60t9
# Scholar 62 = 1852H/1815H/0H/0/63 = addr_test1qrl98h2rr2ltcrhsnsh5n3z5ywnhnx6gtnp90t5gugqel5xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqtvxcrm
# Scholar 63 = 1852H/1815H/0H/0/64 = addr_test1qr0zwzyd6tu9jgzztwcnf3d5s7uupggplxdr8n3h88lzc6xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqq543s5
# Scholar 64 = 1852H/1815H/0H/0/65 = addr_test1qrwd8caaqtnjd4xgv3e8j2nhggxh65fq83uwddvky5xvzdkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqnan585
# Scholar 65 = 1852H/1815H/0H/0/66 = addr_test1qzeaxy5zazmp0edr007qq86w59t5l4s4pp0w4er2aumx73xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqn67xqz
# Scholar 66 = 1852H/1815H/0H/0/67 = addr_test1qq9tsjye0cjs9rjs0xydxjcq5la729ltvzw7t6lqpvj28gxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjfd45w
# Scholar 67 = 1852H/1815H/0H/0/68 = addr_test1qq3vmljj6xr6qsng04uq40ltjjank8y2wtqavgkk582fg0xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq36vy6p
# Scholar 68 = 1852H/1815H/0H/0/69 = addr_test1qz08fqe3n2pglztx8rhh5xa3slh5xtufy7c5c44u49ar6mxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqgj4hyp
# Scholar 69 = 1852H/1815H/0H/0/70 = addr_test1qzg75fn3gzefd5x4fj9396d7l898hjsc5de0hfcehy90epxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7u0w62
# Scholar 70 = 1852H/1815H/0H/0/71 = addr_test1qr7l63r8dg25mzdrarckv0zh9m855mn6he53ha2jtdjd8swr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqpxcwxy
# Scholar 71 = 1852H/1815H/0H/0/72 = addr_test1qrvkc8v843ap7svs650v7ykarmy8az6l58j8gyvlyx9ng4wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqm7cf4s
# Scholar 72 = 1852H/1815H/0H/0/73 = addr_test1qzu0znj2cn7x3rvt0zaq3cjuz4j39h978s0czw0xajux3jkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlw8fme
# Scholar 73 = 1852H/1815H/0H/0/74 = addr_test1qzh92un69kg06t7rtfu4nfjz4xttc4hunwsz7htpqqpfh9kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5egcn6
# Scholar 74 = 1852H/1815H/0H/0/75 = addr_test1qpym6sp643shhfgdqz2t0krc5vldw5hwlrcj9l6qndn8npkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqqknlf8
# Scholar 75 = 1852H/1815H/0H/0/76 = addr_test1qz0sraafpmnzj0ujahuxljjacg36hxeq4lwdxnhfm9uddnxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwjz4kw
# Scholar 76 = 1852H/1815H/0H/0/77 = addr_test1qqlvsfdqcl8hxkn065m3m0v24k5kpuc0n26a3h5kdedtly7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqqz6rz2
# Scholar 77 = 1852H/1815H/0H/0/78 = addr_test1qrqwjg5jvm7898kem96c3gev2pxytzkcfh5cea0epxhhqtkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq3r845y
# Scholar 78 = 1852H/1815H/0H/0/79 = addr_test1qzuqkw9453mm2wqt9x33aduxc2tpjq9czxlq9pxx5tgx8pxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqfkn0j3
# Scholar 79 = 1852H/1815H/0H/0/80 = addr_test1qruhds8vv5w4nd6nlkjewa7aqu9pzff22m8xj0a4aq8myuxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqxy85qu
# Scholar 80 = 1852H/1815H/0H/0/81 = addr_test1qrg45zfejwqx9grrzx3aw0nweym5sjyjkgku2cfzs60u7dwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqv0j247
# Scholar 81 = 1852H/1815H/0H/0/82 = addr_test1qphc67n5pw0drrr8r7xdjeckk4l4pyusddvvruaqz78296xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqp2xh7y
# Scholar 82 = 1852H/1815H/0H/0/83 = addr_test1qp4gr0dhkvv999madce0dhez4x367wkznahkdmtvjv8yz27r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqhl28aq
# Scholar 83 = 1852H/1815H/0H/0/84 = addr_test1qpqnnaatl3yr3fc3aw66d8026mjfddmpqzdgql99yxgfyvwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqazk3gh
# Scholar 84 = 1852H/1815H/0H/0/85 = addr_test1qzqsv0q9js4udx89yrnadnvdd7nuwv750zz2938sg4fa83wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2efdee
# Scholar 85 = 1852H/1815H/0H/0/86 = addr_test1qrcnznq5m5srjasmxrpkdqc7x4mh02vsru0ws8m82v667hxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq8wje78
# Scholar 86 = 1852H/1815H/0H/0/87 = addr_test1qzamldrpyf6rfneflv2jvh4q03m6gug8amp5hce5ww04l7kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq8aa8k9
# Scholar 87 = 1852H/1815H/0H/0/88 = addr_test1qprs6cc7p6xkuyedjrgg3w8g6r82jmvp8hq7zv8lhlshf07r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkplwl4
# Scholar 88 = 1852H/1815H/0H/0/89 = addr_test1qprks5kj24y2r2hdvav6rkdwef2m757epr54xnjc2tr398wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqla8ngy
# Scholar 89 = 1852H/1815H/0H/0/90 = addr_test1qzz0xx5cz6su3kh6gldu7wzp2mhcffytwv0upg43hdkc0nxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqhw08as
# Scholar 90 = 1852H/1815H/0H/0/91 = addr_test1qrjwq07mqh4lhwamstx3gy69meqsvn7pylxtmhfadf7ut6kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqp6e7ud
# Scholar 91 = 1852H/1815H/0H/0/92 = addr_test1qq6peyeak7ftpdwq7lgahssj4s5sslhcgcfd4wfgxtf52xkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwzhdsg
# Scholar 92 = 1852H/1815H/0H/0/93 = addr_test1qzmwzfavsycupvv35xjchq7w4q6yqxz67r5plrwglqsnve7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkktlxy
# Scholar 93 = 1852H/1815H/0H/0/94 = addr_test1qzd3z04g5wlkgztjchdqkgg9j6hysmgk6xsgxf3m37glfl7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqnaeh54
# Scholar 94 = 1852H/1815H/0H/0/95 = addr_test1qqg3rrcvdvz2lrvayeakmt2ahlgv84y29ggjyhya7p80a67r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jquj2zsf
# Scholar 95 = 1852H/1815H/0H/0/96 = addr_test1qq3k3mxh25zclz5hg95rzskf2k5m2z5qwr2ejcyant43evwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqqpmnnz
# Scholar 96 = 1852H/1815H/0H/0/97 = addr_test1qzeexmvhgklvm0sm5a93has8la8xzkalnghulxq07zs84q7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqadklvz
# Scholar 97 = 1852H/1815H/0H/0/98 = addr_test1qz0djqvxvfg7xmpzr98jgmlzv870jg80qctaemrzhx7rx6kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqdqcucz
# Scholar 98 = 1852H/1815H/0H/0/99 = addr_test1qpjsldudrtytstlgkfmy7z6dymu4yra9uperq2chmu9xaukr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq00l0a0
# Scholar 99 = 1852H/1815H/0H/0/100 = addr_test1qzs2warxngdak4jdtmg0q7j2n3yc6gtrmhqwvq4gaq602lxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjxlpdl
# Scholar 100 = 1852H/1815H/0H/0/101 = addr_test1qqtdfkwpjq7amgjvka4czt7cqvxa4zhe3jmaa8jaqpjxfhkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq6hmtxv

# %% [markdown]
# ## Other addresses used in this example

# %% [markdown]
# ### Administartor
#
# The *Administrator* simply provides funds for the example and submits the creation transaction.

# %%
ADMINISTRATOR_NAME=j.lumley
ADMINISTRATOR_SKEY=../keys/$ADMINISTRATOR_NAME.skey
ADMINISTRATOR_ADDR=$(cat ../keys/$ADMINISTRATOR_NAME.testnet.address)
echo "$ADMINISTRATOR_NAME @ $ADMINISTRATOR_ADDR"
# Out:
# j.lumley @ addr_test1vrsuucqupq5xz7dw0tnw7w3cyck5zyk2kpnr56xlhr57m3gll8m84

# %% [markdown]
# Tidy the UTxOs at the administrator's address.

# %%
/extra/iohk/bin/marlowe-cli util clean \
  --change-address "$ADMINISTRATOR_ADDR" \
  --required-signer "$ADMINISTRATOR_SKEY" \
  --out-file /dev/null \
  --submit 600
# Out:
# TxId "d3af75f36ed8331ade46ec82ed22ad5b046e39dfe3365cd1a6f72f9e133f7dc3"

# %% [markdown]
# View the administrator's funds.

# %%
cardano-cli query utxo \
  --testnet-magic "$CARDANO_TESTNET_MAGIC" \
  --address "$ADMINISTRATOR_ADDR"
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# d3af75f36ed8331ade46ec82ed22ad5b046e39dfe3365cd1a6f72f9e133f7dc3     0        41688900411 lovelace + TxOutDatumNone
# d3af75f36ed8331ade46ec82ed22ad5b046e39dfe3365cd1a6f72f9e133f7dc3     1        2000000 lovelace + 2 8bb3b343d8e404472337966a722150048c768d0a92a9813596c5338d.6a2e6c756d6c6579 + TxOutDatumNone

# %% [markdown]
# ### Treasurers
#
# The scholarship funds are held at a multisig address. In this example, we have three *Treasurers* that collectively contract that multisig.

# %%
TREASURER_1_NAME=c.marlowe
TREASURER_1_SKEY=../keys/$TREASURER_1_NAME.skey
TREASURER_1_ADDR=$(cat ../keys/$TREASURER_1_NAME.testnet.address)
TREASURER_1_PKH=$(cardano-cli key verification-key --signing-key-file $TREASURER_1_SKEY --verification-key-file /dev/stdout | cardano-cli address key-hash --verification-key-file /dev/stdin)
echo "$TREASURER_1_NAME @ $TREASURER_1_ADDR"
# Out:
# c.marlowe @ addr_test1vrtntkszteptml4e9ce9l3fsmgavwv4ywunvdnhxv6nw5ksq6737a

# %%
TREASURER_2_NAME=e.cary
TREASURER_2_SKEY=../keys/$TREASURER_2_NAME.skey
TREASURER_2_ADDR=$(cat ../keys/$TREASURER_2_NAME.testnet.address)
TREASURER_2_PKH=$(cardano-cli key verification-key --signing-key-file $TREASURER_2_SKEY --verification-key-file /dev/stdout | cardano-cli address key-hash --verification-key-file /dev/stdin)
echo "$TREASURER_2_NAME @ $TREASURER_2_ADDR"
# Out:
# e.cary @ addr_test1vpkedn0l6slaj8fzkx08qyce9vpreuu3spmnlxkepx4757grxzyzf

# %%
TREASURER_3_NAME=j.webster
TREASURER_3_SKEY=../keys/$TREASURER_3_NAME.skey
TREASURER_3_ADDR=$(cat ../keys/$TREASURER_3_NAME.testnet.address)
TREASURER_3_PKH=$(cardano-cli key verification-key --signing-key-file $TREASURER_3_SKEY --verification-key-file /dev/stdout | cardano-cli address key-hash --verification-key-file /dev/stdin)
echo "$TREASURER_3_NAME @ $TREASURER_3_ADDR"
# Out:
# j.webster @ addr_test1vzgrqnlp6elmettvuelx5vkn0uxhtu2ewqdhx297ukgjmjgpss5k0

# %% [markdown]
# ## Contract Parameters

# %% [markdown]
# ### Deadlines
#
# Start the contract at the current time.

# %%
NOW=$(($(date -u +%s) * 1000))
echo "NOW = $NOW = $(date -d @$((NOW / 1000)))"
# Out:
# NOW = 1683390067000 = Sat May  6 10:21:07 AM MDT 2023

# %%
REDEMPTION_DEADLINE=$(($(date -u +%s) * SECOND + 2 * HOUR))
echo "REDEMPTION_DEADLINE = $REDEMPTION_DEADLINE = $(date -d @$((REDEMPTION_DEADLINE / 1000)))"
# Out:
# REDEMPTION_DEADLINE = 1683397269000 = Sat May  6 12:21:09 PM MDT 2023

# %% [markdown]
# ### Scholarships

# %%
NUMBER_OF_SCHOLARSHIPS=$NUMBER_OF_SCHOLARS
echo "NUMBER_OF_SCHOLARSHIPS = $NUMBER_OF_SCHOLARSHIPS"
# Out:
# NUMBER_OF_SCHOLARSHIPS = 100

# %%
SCHOLARSHIP_AMOUNT=$((400 * ADA))
echo "SCHOLARSHIP_AMOUNT = $SCHOLARSHIP_AMOUNT lovelace"
# Out:
# SCHOLARSHIP_AMOUNT = 400000000 lovelace

# %% [markdown]
# ## Treasury
#
# The *Treasury* is a multisig address that holds the scholarship funds.

# %% [markdown]
# ### Multisig Script
#
# In this example we use an Allegra two-of-three multisig script.

# %%
yaml2json << EOI > multisig.json
type: atLeast
required: 2
scripts:
- keyHash: $TREASURER_1_PKH
  type: sig
- keyHash: $TREASURER_2_PKH
  type: sig
- keyHash: $TREASURER_3_PKH
  type: sig
EOI
cat multisig.json
# Out:
# {"required":2,"scripts":[{"keyHash":"d735da025e42bdfeb92e325fc530da3ac732a47726c6cee666a6ea5a","type":"sig"},{"keyHash":"6d96cdffd43fd91d22b19e7013192b023cf39180773f9ad909abea79","type":"sig"},{"keyHash":"90304fe1d67fbcad6ce67e6a32d37f0d75f159701b7328bee5912dc9","type":"sig"}],"type":"atLeast"}

# %% [markdown]
# Compute the multisig address.

# %%
TREASURY_ADDR=$(cardano-cli address build --testnet-magic "$CARDANO_TESTNET_MAGIC" --payment-script-file multisig.json --stake-verification-key-file ../keys/william-shakespeare.stake.vkey)
echo "TREASURY_ADDR = $TREASURY_ADDR"
# Out:
# TREASURY_ADDR = addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0

# %% [markdown]
# ### Fund the treasury
#
# In this example, the administrator will fund the treasury. Normally, that would be funded by contributors to the scholarship fund.
#
# First find a UTxO that is large enough to fund the treasury.

# %%
TX_IN=$(
marlowe-cli util select \
  --lovelace-only "$((NUMBER_OF_SCHOLARSHIPS * SCHOLARSHIP_AMOUNT + 30 * ADA))" \
  "$ADMINISTRATOR_ADDR" \
| sed -e 's/^TxIn "\(.*\)" (TxIx \(.*\))$/\1#\2/;2,$d' \
)
echo "TX_IN = $TX_IN"
# Out:
# TX_IN = d3af75f36ed8331ade46ec82ed22ad5b046e39dfe3365cd1a6f72f9e133f7dc3#0

# %% [markdown]
# Now fund the treasury.

# %%
TX[1]=$(
/extra/iohk/bin/marlowe-cli transaction simple \
  --tx-in "$TX_IN" \
  --tx-out "$TREASURY_ADDR+$((NUMBER_OF_SCHOLARSHIPS * SCHOLARSHIP_AMOUNT))" \
  --change-address "$ADMINISTRATOR_ADDR" \
  --required-signer "$ADMINISTRATOR_SKEY" \
  --out-file /dev/null \
  --submit 600 \
| sed -e 's/^TxId "\(.*\)"$/\1/' \
)
echo "TX[1] = ${TX[1]}"
# Out:
# TX[1] = 0ebeb800c9d95f63d54711cfd111b3910707eb33bd1716c8f7591f24423024fd

# %% [markdown]
# View the funds in the treasury.

# %%
cardano-cli query utxo --testnet-magic "$CARDANO_TESTNET_MAGIC" --address "$TREASURY_ADDR"
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 0ebeb800c9d95f63d54711cfd111b3910707eb33bd1716c8f7591f24423024fd     1        40000000000 lovelace + TxOutDatumNone

# %% [markdown]
# ## Contracts
#
# Create a separate Marlowe contract for each scholar.
#
# Although each Marlowe contract conceptually includes a `Deposit` block, in practice we bypass that block by initializing the contract's state with the scholarship funds already deposited. This eliminates some fees and it permits the multisig key holders to only sign the creation transaction, not each of the 100 deposit transactions. The actual contract on the chain is as shown below.
#
# ![Scholarship contract](contract-actual.png)
#
# For the first two contracts, we'll set the redemption deadline to the past so that we can execute the timeout case where funds are returned to the treasury. (This is simply for convenience of this example, so we don't have to wait a long time for the deadline to pass.)

# %%
for i in $(seq 1 2)
do
yaml2json << EOI > "contracts/$i.json"
when:
- case:
    for_choice:
      choice_name: Pay Scholarship
      choice_owner:
        address: $VERIFIER_ADDR
    choose_between:
    - from: 0
      to: 0
  then:
    from_account:
      address: $TREASURY_ADDR
    token:
      currency_symbol: ''
      token_name: ''
    pay: $SCHOLARSHIP_AMOUNT
    to:
      party:
        address: ${SCHOLAR_ADDR[$i]}
    then: close
timeout: $NOW
timeout_continuation: close
EOI
done

cat contracts/1.json
# Out:
# {"timeout":1683390067000,"timeout_continuation":"close","when":[{"case":{"choose_between":[{"from":0,"to":0}],"for_choice":{"choice_name":"Pay Scholarship","choice_owner":{"address":"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw"}}},"then":{"from_account":{"address":"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0"},"pay":400000000,"then":"close","to":{"party":{"address":"addr_test1qzenwj7elwatk3mmc368mwnv067fqnuk3x7u4nqw5dezg8wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqf6k36p"}},"token":{"currency_symbol":"","token_name":""}}}]}

# %% [markdown]
# Create the remaining contracts normally, with their redemption deadline in the future.

# %%
for i in $(seq 3 $NUMBER_OF_SCHOLARSHIPS)
do
yaml2json << EOI > "contracts/$i.json"
when:
- case:
    for_choice:
      choice_name: Pay Scholarship
      choice_owner:
        address: $VERIFIER_ADDR
    choose_between:
    - from: 0
      to: 0
  then:
    from_account:
      address: $TREASURY_ADDR
    token:
      currency_symbol: ''
      token_name: ''
    pay: $SCHOLARSHIP_AMOUNT
    to:
      party:
        address: ${SCHOLAR_ADDR[$i]}
    then: close
timeout: $REDEMPTION_DEADLINE
timeout_continuation: close
EOI
done

cat contracts/3.json
# Out:
# {"timeout":1683397269000,"timeout_continuation":"close","when":[{"case":{"choose_between":[{"from":0,"to":0}],"for_choice":{"choice_name":"Pay Scholarship","choice_owner":{"address":"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw"}}},"then":{"from_account":{"address":"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0"},"pay":400000000,"then":"close","to":{"party":{"address":"addr_test1qzlwepx5u26a8w94kfrkfem6njlam22emyhjscu0lxqrce7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5jnrn3"}},"token":{"currency_symbol":"","token_name":""}}}]}

# %% [markdown]
# Make the initial state of each contract contain the scholarship funds.

# %%
for i in $(seq 1 $NUMBER_OF_SCHOLARSHIPS)
do
yaml2json << EOI > "states/$i.json"
accounts:
- - - address: $TREASURY_ADDR
    - currency_symbol: ''
      token_name: ''
  - $SCHOLARSHIP_AMOUNT
boundValues: []
choices: []
minTime: 1
EOI
done

cat states/1.json
# Out:
# {"accounts":[[[{"address":"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0"},{"currency_symbol":"","token_name":""}],400000000]],"boundValues":[],"choices":[],"minTime":1}

# %% [markdown]
# Compute the datum hash for each contract.

# %%
for i in $(seq 1 $NUMBER_OF_SCHOLARSHIPS)
do
marlowe-cli run initialize \
  --permanently-without-staking \
  --stake-address "$STAKE_ADDR" \
  --contract-file "contracts/$i.json" \
  --state-file "states/$i.json" \
  --out-file "marlowes/${i}a.json"
DATUM_HASH[$i]=$(
marlowe-cli contract datum \
 --contract-file "contracts/$i.json" \
 --state-file "states/$i.json" \
 --out-file /dev/null
)
echo "DATUM_HASH[$i] = ${DATUM_HASH[$i]}"
done
# Out:
# DATUM_HASH[1] = 54a6d8e970e757f815dea5fbb21b65aee7f7a1b5e4852ff83dff684f1cb2abdc
# DATUM_HASH[2] = 318bd42feb3a44c971fe13048d7b5b491124e96413579be3e1a8032c92ca1b19
# DATUM_HASH[3] = f889a9a9d3f2fe7e593738de4b2d9c6a52a80cdf13ab41264c7306771774c306
# DATUM_HASH[4] = 4d7ed021621bed1c790791c99cbaa0c80d0a15f2502eb5257c7f75d3240d686a
# DATUM_HASH[5] = 54c6924a6e7bc67be4c968de22212d8a99ad933c227f9df3870ee34fe74eaf30
# DATUM_HASH[6] = 90bdd0273982bacb3182ccf9484a7dfac99de857967fde2cc72d8721d13ffdd2
# DATUM_HASH[7] = a633fa3d2772c3c981ded298b91fcb5868e693d64a81a42bccaae0272251c0fe
# DATUM_HASH[8] = 7ff00e4c787ae4fb29a8fd0c05c63e293908974893921915974fb8d975df7b7b
# DATUM_HASH[9] = 1e59cf0685d8615a74709e75e88078ed5624b842e709c45a8c2ba77d8d660ac2
# DATUM_HASH[10] = 99cd51948fe6b6e762dea2d02c24f58611e5a768dc1fe15f93bdc0233bf428e1
# DATUM_HASH[11] = a1448ee00466479ab1736bed8157737040b949cecc8c3d2b6d335aa350ba1652
# DATUM_HASH[12] = 0da707efde65a6700d00a44f5e7640bb84f2d1a254184f01e4d22f891e26b73f
# DATUM_HASH[13] = c1d6cc2b34688ae32f2f70839af5d239de4b600938854d3c3e3426e89a26e6da
# DATUM_HASH[14] = 2ac7a37a8dbfaa4becda37fe301bd4893ddb7305b3ac0f1dbad117f61ab93267
# DATUM_HASH[15] = 6e738a12d97ad697d9e43a246062886c5937516d4d9e2c884a45efd096813628
# DATUM_HASH[16] = 7cd7bba9e0153106c23a6331ebbcaea22447676957c90fab6b883d2041931bdb
# DATUM_HASH[17] = f535cb311e5b2c824e290c5f1c505c8fc8f7c966f9b64eb9fd8823b3037e8405
# DATUM_HASH[18] = 6f31749720084aa9b7c65af52a1ebc3dadd0e5536bf955e7683662b2f4b26f42
# DATUM_HASH[19] = ea4e124abe152317728de8140af228bdc855a1f36aca2f4e488fa4196670a992
# DATUM_HASH[20] = c514b76c6927e4f00bf8d288aa9988827c5e25573d5732a0e0cb8759ab6f97ea
# DATUM_HASH[21] = 7bb7dc92abbfaca01bb58b9ddc573ce99dbe7fc79e14fc09d6207ee4e3511708
# DATUM_HASH[22] = a157f1fbafd31ce80c35fc662b6c8ed49c4f73b36039d42710e351848702a17e
# DATUM_HASH[23] = 277aa5d5cf15c5d0360d588ce9a24d16ac8dbadf449201c36f5ac71d9e04beca
# DATUM_HASH[24] = 640ec1fe5ee5d526e9fa4e5ba03d65351bdd4bdf2ab45be0fc6a983c2d73ccc3
# DATUM_HASH[25] = 66874d5af5c60b620dd9b34f55cda87b3c3e398e75a6663ae917676bba7ad107
# DATUM_HASH[26] = fb9471e6e5329a531a3cd54bbebf1aef455aaada5e53282a43e75b313819a791
# DATUM_HASH[27] = 0dfc54b2e010a7312902805d190abd34c303cde9bb317a3c089e91257e4076c5
# DATUM_HASH[28] = 377c90d095aff3eb48ea62c3165e700df37582183722a2ca834b32b557eebbd3
# DATUM_HASH[29] = cee25d64702fc0675c39c08fb06e62d289e6673993cee074df8a95109e9f0c7f
# DATUM_HASH[30] = 0e1664d5561d2bba548a82cdc302916b5bacb5258e9bf85c3fa4c1f17f70e939
# DATUM_HASH[31] = 57829175ebf6028b6817a8f0cfd05343dfef7d5932a96cd5c403eeb801a222ca
# DATUM_HASH[32] = 659fc9fc65efec7bcaafafb6453f3fcdb824ea42c47134bba0a02da7b96dae46
# DATUM_HASH[33] = f17821a2fe0ee4060e20d83c7fdf48fead95be467ca9254f026488dfed004467
# DATUM_HASH[34] = c7b506bf880af9f88652025c4b9ee6c15803bf8c28646b1f25c27b0d9af66322
# DATUM_HASH[35] = 052b87947dd90a686f55610abb209d6b6ea89a65f01ea3ebe0be2ba09ae041d8
# DATUM_HASH[36] = e9c20ababdb7c10e29093d01efcaa9fd663dd6d296af94326d90b4411373aaf1
# DATUM_HASH[37] = cfbb3480f6ee6affc63a05dde0756eb8951482cb160050c8b3146fb7228b19a8
# DATUM_HASH[38] = e282066a4f7dd03dabbfafd9a2a3e56a27270c5f10dd0371ea99079f6b46afd7
# DATUM_HASH[39] = 211eaec29eb71cc650f4e6e14e3d2ba9c3692b8be65efe1669205e9c79b227d4
# DATUM_HASH[40] = 29179ef0bb3c457f8fa9b41d1989722c403871508067bc90855303d5fbfa23a5
# DATUM_HASH[41] = bc061313ca7f818ee6efc486235cf2935f03392faec2f6358e714665f2161d6d
# DATUM_HASH[42] = dc8597374df1c23359ac2c8c8b158caa0123e8a5486c0075d560aab13fd37a2c
# DATUM_HASH[43] = cc467dde6cadf7417502f189c34fec7e36587c033aff0382c49e1ff65c1965b4
# DATUM_HASH[44] = f7d1cfe248a5ee19b9b07a35cc08f7f6b7148571f551a0992f5bb599936cd15c
# DATUM_HASH[45] = 405267efc2433749e9f13c1c78d7694f60e12d5224b7f85740e934683ce86a4d
# DATUM_HASH[46] = 9914a0dad0dfa93c98fc6a48accdc9eaa944989e9156040365796f7afce85d93
# DATUM_HASH[47] = b42872ed5cf15a04dccc35c225648bf35011fd6dff5eef41a7329043c9842581
# DATUM_HASH[48] = 308634c8e2962ae38964e6cb05e15de42120f299af05f9653ca4b36339d69016
# DATUM_HASH[49] = 7c75288fda7ba11044f1b3477937cd75d33367a1f431486af880e2b9ebca4750
# DATUM_HASH[50] = e77e64450aa6fe13599322906d196f45b8620d2b4f02ce4d6600b8545ae5728f
# DATUM_HASH[51] = c2ac73e5a24df3b714a1e7c5433ebb6723ecf0b11d81d756935ea28980f288dc
# DATUM_HASH[52] = 63c0f776775fb398e8d3edcc713f9ca0707a16007f303b2a6ed14fedcfe5e48b
# DATUM_HASH[53] = ef2e7be7de57df74cdbe2d855e5b58ad4106076f57bdb69e0b94eebdc1778246
# DATUM_HASH[54] = 4fef1df2181d0a03d7fa17ffe2c0308359ce8f017e10c63d922a03967af73c1d
# DATUM_HASH[55] = a6857afae8a128fe6be7bb83837531b12751d8a82460a1fa6b40fb48b1287a00
# DATUM_HASH[56] = 6ec64c6d116946668428ef9ff0af6f4083b0d48e4627747d6fa856663cd9ae82
# DATUM_HASH[57] = f38ef399378cb0144109b6b7ba7eb1ce59c1eea46eaa09fd364a41f667abfaa8
# DATUM_HASH[58] = 0b4eb96e26ad70326c1c93de8c023da22de05e1f8ed8c8d5f3b588c1a77f673e
# DATUM_HASH[59] = 8f4bb10b8ff07e245bcef5c29e1579b7345397c20874f533210be6b4ae1a69f3
# DATUM_HASH[60] = 99b105eaca543900db4d23bc808ef266ffe328916828b610af5c33a956bf3c85
# DATUM_HASH[61] = c855a1962b01562ad844f9fdffa79162eb7c05854b4ef73f15e0312d81a37200
# DATUM_HASH[62] = 96f15c33b236ac4e7369923ff12b8c31cb029ad677ebb3f3c1ee8ecf671afd0d
# DATUM_HASH[63] = 2d4a97c3f811cbec320b6051d0e62e964958b68edf44be42d75e0a27c9fb8b6d
# DATUM_HASH[64] = 55581678ac82f12dd14b654452df35911740b1c3153497e57a13584806f9ad77
# DATUM_HASH[65] = c468566573cba04d60b26a1aff9a1a77ac487b5dcaa7259cd00c5b3bb0d882aa
# DATUM_HASH[66] = 7d0572f82e69db13aab2ade9c66c461d8cccca1823c448cccc28f068402175d6
# DATUM_HASH[67] = bf43f6351df8a606e593c03f448184f9778adbbcc0cccf9dfbd1703964e3cff0
# DATUM_HASH[68] = c1a54059a3a4a9e1d11a51806209e81a2eda962522a9464f0b45c164052cd2e7
# DATUM_HASH[69] = 29d8ebb0a1e64682598b9684498e376efaf476a6ee14a1e9e7360590b583e6f8
# DATUM_HASH[70] = a4220d5854124d4728c4a2eb766efb0970feeca79ceece7fa3a73fdd168a6c7f
# DATUM_HASH[71] = 29724345b3df5b97f345633a8c0ae178effc978201afb55b3d4718c978eab149
# DATUM_HASH[72] = 65e2433c1946756fc9618e38178b7d0bb83aeeeec2ad1a4e6ce0605a97bc073c
# DATUM_HASH[73] = 6d3ba79895d264fe332fe09c22ae8866cde1b74e96f887b86d994222e8b665f1
# DATUM_HASH[74] = 467593898221d3c6e331edaf532f6183eca659fabdca6e8b3586f6fae1d12aeb
# DATUM_HASH[75] = e8b49c847bbbe70e1dd342493d905cfd59377772a582a8de374d51a83cfe02c5
# DATUM_HASH[76] = 85caee263f0680b72767845cd1787d157ac1325b2688088f48918da86ea386f3
# DATUM_HASH[77] = b123b39ebea617942ce3d3c643fc9ff6c1c42a8b393c34da5ca53f2dd1515631
# DATUM_HASH[78] = 6c442111dedac6953bfbd463199e0979866b14b9dd5032c7320ae38e7a6cf360
# DATUM_HASH[79] = 090dcbb0b207b355190d2584af973342a38cda1cece4d98443a8226417f4912c
# DATUM_HASH[80] = 72adcce6c28cb61ebe5867a588091a9ae8d3d38500194942167233461690ce9e
# DATUM_HASH[81] = adfb4bdfe1caab97c3ab8a13641cd71338152c1dbc22ccf7be04a87524f9e0bf
# DATUM_HASH[82] = 02471f39276008c31fe226e512b6343d010dc7780eb59473c0045e1d6b8f86b1
# DATUM_HASH[83] = 9fe741e0fab7c0438dbb2e54d1c2904fc854f7e94ba5681f039a56a1bab177ec
# DATUM_HASH[84] = 221c4be1aca055824a8db7028f9bb0b84d5def8e2ca48a82cc011fa65c0bdaf7
# DATUM_HASH[85] = 883f535007146007286f165cdbe15546736ba9559454c314f631031d6a1fb0e6
# DATUM_HASH[86] = 3bc8a03e126988c47a43da165f57b32aa00a3a081c812e1bd4d535433cd4f2e0
# DATUM_HASH[87] = 2e9388ed7f5257e50613ceebb7b45de4040bd1ca036fa86fcf06df6530852b73
# DATUM_HASH[88] = 500c02afec44990c9fc25783a293f41f14937f1a2587f5a9f861bcc80a8f7660
# DATUM_HASH[89] = 4121e07deb05e3a6c8f5715a3682eaacd4700a575efd652a80e2bcf85544fa42
# DATUM_HASH[90] = 8eb3c51fcca368dacc47c4ca08908360861f4ab603f72ba34d8e9a18a45e7748
# DATUM_HASH[91] = 931ff7a6fc79491f792a320b4541e7252d78cc8c502a4e682afc78ea2aa2cb51
# DATUM_HASH[92] = 416503fcaa945599791fbbf1d5a2761c8b2dfa562088b8e3fef402e1fc94bd6d
# DATUM_HASH[93] = 92dada31c76a0ad7e1a42453e9e611982fa4791465aa341338d557acaa2c4819
# DATUM_HASH[94] = e42317f58fd9bf4f38f803e8f3c31a0658ea483629534939ea60bd6d6b79f493
# DATUM_HASH[95] = c6de7a42fc86a1e3a1cf5c3d054f0395c2ac7b5a688b6723eaac6ff51567cfd2
# DATUM_HASH[96] = 59d1b3394cf1ce80c16e41ed2ba645f75d93a33cf55892e3ddc64d67c163219d
# DATUM_HASH[97] = 3e2062819f29c885c880faaf15840b91abe3de5f8bf8fe1632436226f246f518
# DATUM_HASH[98] = 9b3f7251a08b5bfba92f2282ce417c53aed91b354320b25eabd2b5bab835c0f2
# DATUM_HASH[99] = c24ee3d52428f1f3ee0225c2014a0de4b2a398b3c806b5cacd6c61eda44d9c46
# DATUM_HASH[100] = 211e8b4b8a3b2a26cd09f574228a6fd3d1b829aac08367db0df31ca2316100f3

# %% [markdown]
# ## Creation transaction
#
# The creation transaction will move funds from the treasury into separate contracts for each scholar. These contracts all reside at the address of Marlowe's semantics validator.

# %%
MARLOWE_ADDR=$(jq -r '.tx.marloweValidator.address' marlowes/1a.json)
echo "MARLOWE_ADDR = $MARLOWE_ADDR"
# Out:
# MARLOWE_ADDR = addr_test1zqhdyccahvnheppng3fut3phhp3jt5m37zp4529ezz535mkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqc6s825

# %% [markdown]
# The administrator will pay the transaction fee, so find one of their UTxOs with sufficient funds.

# %%
TX_IN=$(
marlowe-cli util select \
  --lovelace-only "$((10 * ADA))" \
  "$ADMINISTRATOR_ADDR" \
| sed -e 's/^TxIn "\(.*\)" (TxIx \(.*\))$/\1#\2/;2,$d' \
)
echo "TX_IN = ${TX_IN}"
# Out:
# TX_IN = 0ebeb800c9d95f63d54711cfd111b3910707eb33bd1716c8f7591f24423024fd#0

# %% [markdown]
# Now build a transaction that sends the treasury funds to the scholarship contract.
#
# ***Important notes:***
# * If the treasury contains excess funds, a change output back to the treasury must be added to the command below.
# * This command assumes that treasury funds have been consolidated into a single UTxO.

# %%
cardano-cli transaction build \
  --testnet-magic "$CARDANO_TESTNET_MAGIC" \
  --babbage-era \
  --tx-in "$TX_IN" \
  --tx-in "${TX[1]}#1" \
    --tx-in-script-file multisig.json \
  $(for i in $(seq 1 $NUMBER_OF_SCHOLARSHIPS); do echo "--tx-out $MARLOWE_ADDR+$SCHOLARSHIP_AMOUNT --tx-out-datum-hash ${DATUM_HASH[$i]}"; done) \
  --change-address "$ADMINISTRATOR_ADDR" \
  --witness-override 4 \
  --out-file txs/2.unsigned
# Out:
# Estimated transaction fee: Lovelace 641053

# %% [markdown]
# Submit the transaction to create the contracts.

# %%
TX[2]=$(
/extra/iohk/bin/marlowe-cli transaction submit \
  --tx-body-file txs/2.unsigned \
  --required-signer "$ADMINISTRATOR_SKEY" \
  --required-signer "$TREASURER_1_SKEY" \
  --required-signer "$TREASURER_2_SKEY" \
  --required-signer "$TREASURER_3_SKEY" \
  --timeout 600 \
| sed -e 's/^TxId "\(.*\)"$/\1/' \
)
echo "TX[2] = ${TX[2]}"
# Out:
# TX[2] = 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae

# %% [markdown]
# View the contracts at the address of the Marlowe semantics validator.

# %%
cardano-cli query utxo --testnet-magic "$CARDANO_TESTNET_MAGIC" --address "$MARLOWE_ADDR"
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     1        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "54a6d8e970e757f815dea5fbb21b65aee7f7a1b5e4852ff83dff684f1cb2abdc"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     2        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "318bd42feb3a44c971fe13048d7b5b491124e96413579be3e1a8032c92ca1b19"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     3        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "f889a9a9d3f2fe7e593738de4b2d9c6a52a80cdf13ab41264c7306771774c306"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     4        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "4d7ed021621bed1c790791c99cbaa0c80d0a15f2502eb5257c7f75d3240d686a"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     5        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "54c6924a6e7bc67be4c968de22212d8a99ad933c227f9df3870ee34fe74eaf30"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     6        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "90bdd0273982bacb3182ccf9484a7dfac99de857967fde2cc72d8721d13ffdd2"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     7        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "a633fa3d2772c3c981ded298b91fcb5868e693d64a81a42bccaae0272251c0fe"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     8        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "7ff00e4c787ae4fb29a8fd0c05c63e293908974893921915974fb8d975df7b7b"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae     9        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "1e59cf0685d8615a74709e75e88078ed5624b842e709c45a8c2ba77d8d660ac2"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    10        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "99cd51948fe6b6e762dea2d02c24f58611e5a768dc1fe15f93bdc0233bf428e1"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    11        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "a1448ee00466479ab1736bed8157737040b949cecc8c3d2b6d335aa350ba1652"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    12        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "0da707efde65a6700d00a44f5e7640bb84f2d1a254184f01e4d22f891e26b73f"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    13        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c1d6cc2b34688ae32f2f70839af5d239de4b600938854d3c3e3426e89a26e6da"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    14        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "2ac7a37a8dbfaa4becda37fe301bd4893ddb7305b3ac0f1dbad117f61ab93267"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    15        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "6e738a12d97ad697d9e43a246062886c5937516d4d9e2c884a45efd096813628"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    16        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "7cd7bba9e0153106c23a6331ebbcaea22447676957c90fab6b883d2041931bdb"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    17        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "f535cb311e5b2c824e290c5f1c505c8fc8f7c966f9b64eb9fd8823b3037e8405"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    18        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "6f31749720084aa9b7c65af52a1ebc3dadd0e5536bf955e7683662b2f4b26f42"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    19        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "ea4e124abe152317728de8140af228bdc855a1f36aca2f4e488fa4196670a992"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    20        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c514b76c6927e4f00bf8d288aa9988827c5e25573d5732a0e0cb8759ab6f97ea"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    21        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "7bb7dc92abbfaca01bb58b9ddc573ce99dbe7fc79e14fc09d6207ee4e3511708"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    22        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "a157f1fbafd31ce80c35fc662b6c8ed49c4f73b36039d42710e351848702a17e"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    23        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "277aa5d5cf15c5d0360d588ce9a24d16ac8dbadf449201c36f5ac71d9e04beca"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    24        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "640ec1fe5ee5d526e9fa4e5ba03d65351bdd4bdf2ab45be0fc6a983c2d73ccc3"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    25        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "66874d5af5c60b620dd9b34f55cda87b3c3e398e75a6663ae917676bba7ad107"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    26        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "fb9471e6e5329a531a3cd54bbebf1aef455aaada5e53282a43e75b313819a791"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    27        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "0dfc54b2e010a7312902805d190abd34c303cde9bb317a3c089e91257e4076c5"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    28        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "377c90d095aff3eb48ea62c3165e700df37582183722a2ca834b32b557eebbd3"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    29        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "cee25d64702fc0675c39c08fb06e62d289e6673993cee074df8a95109e9f0c7f"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    30        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "0e1664d5561d2bba548a82cdc302916b5bacb5258e9bf85c3fa4c1f17f70e939"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    31        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "57829175ebf6028b6817a8f0cfd05343dfef7d5932a96cd5c403eeb801a222ca"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    32        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "659fc9fc65efec7bcaafafb6453f3fcdb824ea42c47134bba0a02da7b96dae46"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    33        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "f17821a2fe0ee4060e20d83c7fdf48fead95be467ca9254f026488dfed004467"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    34        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c7b506bf880af9f88652025c4b9ee6c15803bf8c28646b1f25c27b0d9af66322"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    35        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "052b87947dd90a686f55610abb209d6b6ea89a65f01ea3ebe0be2ba09ae041d8"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    36        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "e9c20ababdb7c10e29093d01efcaa9fd663dd6d296af94326d90b4411373aaf1"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    37        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "cfbb3480f6ee6affc63a05dde0756eb8951482cb160050c8b3146fb7228b19a8"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    38        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "e282066a4f7dd03dabbfafd9a2a3e56a27270c5f10dd0371ea99079f6b46afd7"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    39        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "211eaec29eb71cc650f4e6e14e3d2ba9c3692b8be65efe1669205e9c79b227d4"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    40        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "29179ef0bb3c457f8fa9b41d1989722c403871508067bc90855303d5fbfa23a5"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    41        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "bc061313ca7f818ee6efc486235cf2935f03392faec2f6358e714665f2161d6d"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    42        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "dc8597374df1c23359ac2c8c8b158caa0123e8a5486c0075d560aab13fd37a2c"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    43        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "cc467dde6cadf7417502f189c34fec7e36587c033aff0382c49e1ff65c1965b4"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    44        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "f7d1cfe248a5ee19b9b07a35cc08f7f6b7148571f551a0992f5bb599936cd15c"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    45        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "405267efc2433749e9f13c1c78d7694f60e12d5224b7f85740e934683ce86a4d"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    46        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "9914a0dad0dfa93c98fc6a48accdc9eaa944989e9156040365796f7afce85d93"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    47        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "b42872ed5cf15a04dccc35c225648bf35011fd6dff5eef41a7329043c9842581"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    48        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "308634c8e2962ae38964e6cb05e15de42120f299af05f9653ca4b36339d69016"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    49        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "7c75288fda7ba11044f1b3477937cd75d33367a1f431486af880e2b9ebca4750"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    50        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "e77e64450aa6fe13599322906d196f45b8620d2b4f02ce4d6600b8545ae5728f"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    51        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c2ac73e5a24df3b714a1e7c5433ebb6723ecf0b11d81d756935ea28980f288dc"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    52        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "63c0f776775fb398e8d3edcc713f9ca0707a16007f303b2a6ed14fedcfe5e48b"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    53        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "ef2e7be7de57df74cdbe2d855e5b58ad4106076f57bdb69e0b94eebdc1778246"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    54        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "4fef1df2181d0a03d7fa17ffe2c0308359ce8f017e10c63d922a03967af73c1d"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    55        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "a6857afae8a128fe6be7bb83837531b12751d8a82460a1fa6b40fb48b1287a00"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    56        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "6ec64c6d116946668428ef9ff0af6f4083b0d48e4627747d6fa856663cd9ae82"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    57        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "f38ef399378cb0144109b6b7ba7eb1ce59c1eea46eaa09fd364a41f667abfaa8"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    58        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "0b4eb96e26ad70326c1c93de8c023da22de05e1f8ed8c8d5f3b588c1a77f673e"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    59        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "8f4bb10b8ff07e245bcef5c29e1579b7345397c20874f533210be6b4ae1a69f3"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    60        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "99b105eaca543900db4d23bc808ef266ffe328916828b610af5c33a956bf3c85"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    61        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c855a1962b01562ad844f9fdffa79162eb7c05854b4ef73f15e0312d81a37200"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    62        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "96f15c33b236ac4e7369923ff12b8c31cb029ad677ebb3f3c1ee8ecf671afd0d"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    63        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "2d4a97c3f811cbec320b6051d0e62e964958b68edf44be42d75e0a27c9fb8b6d"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    64        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "55581678ac82f12dd14b654452df35911740b1c3153497e57a13584806f9ad77"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    65        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c468566573cba04d60b26a1aff9a1a77ac487b5dcaa7259cd00c5b3bb0d882aa"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    66        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "7d0572f82e69db13aab2ade9c66c461d8cccca1823c448cccc28f068402175d6"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    67        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "bf43f6351df8a606e593c03f448184f9778adbbcc0cccf9dfbd1703964e3cff0"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    68        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c1a54059a3a4a9e1d11a51806209e81a2eda962522a9464f0b45c164052cd2e7"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    69        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "29d8ebb0a1e64682598b9684498e376efaf476a6ee14a1e9e7360590b583e6f8"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    70        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "a4220d5854124d4728c4a2eb766efb0970feeca79ceece7fa3a73fdd168a6c7f"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    71        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "29724345b3df5b97f345633a8c0ae178effc978201afb55b3d4718c978eab149"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    72        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "65e2433c1946756fc9618e38178b7d0bb83aeeeec2ad1a4e6ce0605a97bc073c"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    73        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "6d3ba79895d264fe332fe09c22ae8866cde1b74e96f887b86d994222e8b665f1"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    74        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "467593898221d3c6e331edaf532f6183eca659fabdca6e8b3586f6fae1d12aeb"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    75        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "e8b49c847bbbe70e1dd342493d905cfd59377772a582a8de374d51a83cfe02c5"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    76        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "85caee263f0680b72767845cd1787d157ac1325b2688088f48918da86ea386f3"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    77        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "b123b39ebea617942ce3d3c643fc9ff6c1c42a8b393c34da5ca53f2dd1515631"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    78        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "6c442111dedac6953bfbd463199e0979866b14b9dd5032c7320ae38e7a6cf360"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    79        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "090dcbb0b207b355190d2584af973342a38cda1cece4d98443a8226417f4912c"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    80        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "72adcce6c28cb61ebe5867a588091a9ae8d3d38500194942167233461690ce9e"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    81        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "adfb4bdfe1caab97c3ab8a13641cd71338152c1dbc22ccf7be04a87524f9e0bf"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    82        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "02471f39276008c31fe226e512b6343d010dc7780eb59473c0045e1d6b8f86b1"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    83        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "9fe741e0fab7c0438dbb2e54d1c2904fc854f7e94ba5681f039a56a1bab177ec"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    84        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "221c4be1aca055824a8db7028f9bb0b84d5def8e2ca48a82cc011fa65c0bdaf7"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    85        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "883f535007146007286f165cdbe15546736ba9559454c314f631031d6a1fb0e6"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    86        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "3bc8a03e126988c47a43da165f57b32aa00a3a081c812e1bd4d535433cd4f2e0"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    87        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "2e9388ed7f5257e50613ceebb7b45de4040bd1ca036fa86fcf06df6530852b73"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    88        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "500c02afec44990c9fc25783a293f41f14937f1a2587f5a9f861bcc80a8f7660"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    89        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "4121e07deb05e3a6c8f5715a3682eaacd4700a575efd652a80e2bcf85544fa42"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    90        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "8eb3c51fcca368dacc47c4ca08908360861f4ab603f72ba34d8e9a18a45e7748"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    91        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "931ff7a6fc79491f792a320b4541e7252d78cc8c502a4e682afc78ea2aa2cb51"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    92        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "416503fcaa945599791fbbf1d5a2761c8b2dfa562088b8e3fef402e1fc94bd6d"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    93        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "92dada31c76a0ad7e1a42453e9e611982fa4791465aa341338d557acaa2c4819"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    94        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "e42317f58fd9bf4f38f803e8f3c31a0658ea483629534939ea60bd6d6b79f493"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    95        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c6de7a42fc86a1e3a1cf5c3d054f0395c2ac7b5a688b6723eaac6ff51567cfd2"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    96        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "59d1b3394cf1ce80c16e41ed2ba645f75d93a33cf55892e3ddc64d67c163219d"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    97        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "3e2062819f29c885c880faaf15840b91abe3de5f8bf8fe1632436226f246f518"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    98        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "9b3f7251a08b5bfba92f2282ce417c53aed91b354320b25eabd2b5bab835c0f2"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae    99        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "c24ee3d52428f1f3ee0225c2014a0de4b2a398b3c806b5cacd6c61eda44d9c46"
# 48f23b4f32006849a0f5ed76f32229d0f615b0bb2b79a11f329864c8b0c237ae   100        400000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "211e8b4b8a3b2a26cd09f574228a6fd3d1b829aac08367db0df31ca2316100f3"
# b08b9339982754fb0a67fdb3fcbe73c3f8700dc874ff3e31ab7aad53176dada7     1        5000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "3a23f75042d8c56d85972818a772cdeb4a78ecb17f7a945a6fcc0726115169e1"
# b08b9339982754fb0a67fdb3fcbe73c3f8700dc874ff3e31ab7aad53176dada7     2        5000000 lovelace + TxOutDatumHash ScriptDataInBabbageEra "6a6ffbd983b8e9a4ce35deb14485ca652293d51a7023b447f83b563c8462faed"

# %% [markdown]
# ## Distribute the scholarships
#
# For each scholar, the verifier attests whether they have earned the scholarship. This causes the scholarship funds to be sent to that scholar's address. If the verifier does not make the attestation, then the funds are returned to the treasury.
#
# First execute the first two scholarships, where the verifier ***does not*** make the attestation, so the funds are returned to the treasury.

# %%
for i in $(seq 1 2)
do

n=$((i + 2))

echo
echo "----- Contract $i -----"
echo

marlowe-cli run prepare \
  --invalid-before "$((($(date -u +%s) - 1 * 60) * 1000))" \
  --invalid-hereafter "$((($(date -u +%s) + 5 * 60) * 1000))" \
  --marlowe-file "marlowes/${i}a.json" \
  --out-file "marlowes/${i}b.json"

TX[$n]=$(
/extra/iohk/bin/marlowe-cli run auto-execute \
  --tx-in-marlowe "${TX[2]}#$i" \
  --marlowe-in-file "marlowes/${i}a.json" \
  --marlowe-out-file "marlowes/${i}b.json" \
  --change-address "$VERIFIER_ADDR" \
  --required-signer "$VERIFIER_SKEY" \
  --out-file /dev/null \
  --submit 600 \
| sed -e 's/^TxId "\(.*\)"$/\1/' \
)
echo "TX[$n] = ${TX[$n]}"  

echo
echo "Funds at scholar $i's address:"
cardano-cli query utxo --testnet-magic "$CARDANO_TESTNET_MAGIC" --address "${SCHOLAR_ADDR[$i]}"

echo
echo "Funds in the treasury:"
cardano-cli query utxo --testnet-magic "$CARDANO_TESTNET_MAGIC" --address "$TREASURY_ADDR"

done
# Out:
# ----- Contract 1 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390534000},POSIXTime {getPOSIXTime = 1683390894999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390534000},POSIXTime {getPOSIXTime = 1683390894999}), txInputs = []}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[3] = e09c80cfd8ae1fd99711e34f63e637255289430ff5b17a4bdd7d901069a4f614
#
# Funds at scholar 1's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
#
# Funds in the treasury:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# e09c80cfd8ae1fd99711e34f63e637255289430ff5b17a4bdd7d901069a4f614     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 2 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390589000},POSIXTime {getPOSIXTime = 1683390949999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390589000},POSIXTime {getPOSIXTime = 1683390949999}), txInputs = []}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[4] = 3cd6252ed31ee995030ee8e8c017f89934566ac154b463dce8ca7b4abca55cb9
#
# Funds at scholar 2's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
#
# Funds in the treasury:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 3cd6252ed31ee995030ee8e8c017f89934566ac154b463dce8ca7b4abca55cb9     1        400000000 lovelace + TxOutDatumNone
# e09c80cfd8ae1fd99711e34f63e637255289430ff5b17a4bdd7d901069a4f614     1        400000000 lovelace + TxOutDatumNone

# %% [markdown]
# Now execute the remain scholarships, where the verifier ***does*** make the attestation.

# %%
for i in $(seq 3 $NUMBER_OF_SCHOLARSHIPS)
do

n=$((i + 2))

echo
echo "----- Contract $i -----"
echo

marlowe-cli run prepare \
  --choice-party "$VERIFIER_ADDR" \
  --choice-name "Pay Scholarship" \
  --choice-number 0 \
  --invalid-before "$((($(date -u +%s) - 1 * 60) * 1000))" \
  --invalid-hereafter "$((($(date -u +%s) + 5 * 60) * 1000))" \
  --marlowe-file "marlowes/${i}a.json" \
  --out-file "marlowes/${i}b.json"

TX[$n]=$(
/extra/iohk/bin/marlowe-cli run auto-execute \
  --tx-in-marlowe "${TX[2]}#$i" \
  --marlowe-in-file "marlowes/${i}a.json" \
  --marlowe-out-file "marlowes/${i}b.json" \
  --change-address "$VERIFIER_ADDR" \
  --required-signer "$VERIFIER_SKEY" \
  --out-file /dev/null \
  --submit 600 \
| sed -e 's/^TxId "\(.*\)"$/\1/' \
)
echo "TX[$n] = ${TX[$n]}"  

echo
echo "Funds at scholar $i's address:"
cardano-cli query utxo --testnet-magic "$CARDANO_TESTNET_MAGIC" --address "${SCHOLAR_ADDR[$i]}"

done
# Out:
# ----- Contract 3 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390628000},POSIXTime {getPOSIXTime = 1683390988999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390628000},POSIXTime {getPOSIXTime = 1683390988999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzlwepx5u26a8w94kfrkfem6njlam22emyhjscu0lxqrce7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5jnrn3\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[5] = 27eaf5444c01291bd205a1cce1ec70202ed89fd4fe7842f0da94ef2053769c48
#
# Funds at scholar 3's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 27eaf5444c01291bd205a1cce1ec70202ed89fd4fe7842f0da94ef2053769c48     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 4 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390704000},POSIXTime {getPOSIXTime = 1683391064999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390704000},POSIXTime {getPOSIXTime = 1683391064999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqjrjfslev50d5jn6qdeztxsqvuaaefq6e4hu55n59grjj7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwhulyr\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[6] = d7eaf9b5aa7d2727138249bfc561f294afb4540a5b956d1fb81961b7b1c2f2fe
#
# Funds at scholar 4's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# d7eaf9b5aa7d2727138249bfc561f294afb4540a5b956d1fb81961b7b1c2f2fe     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 5 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390755000},POSIXTime {getPOSIXTime = 1683391115999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390755000},POSIXTime {getPOSIXTime = 1683391115999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqxrzfv0v8l0lahyc5qsgpug66dafp8njl278g0pter7e3xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqcjuuw0\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[7] = ffb39a9715691e6d2c64d9262479bab55e2faf7eb572c571b288bdd1362d65ba
#
# Funds at scholar 5's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ffb39a9715691e6d2c64d9262479bab55e2faf7eb572c571b288bdd1362d65ba     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 6 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390781000},POSIXTime {getPOSIXTime = 1683391141999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390781000},POSIXTime {getPOSIXTime = 1683391141999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqqfzyuqkvrr7ajgk887sqac8lgzatc6el9uxke4x5g5dg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkmrpwu\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[8] = c97e2848152f69776d8947a719b4e6d9aa9f63e8162bea197be69b3f4205e21a
#
# Funds at scholar 6's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# c97e2848152f69776d8947a719b4e6d9aa9f63e8162bea197be69b3f4205e21a     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 7 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390827000},POSIXTime {getPOSIXTime = 1683391187999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390827000},POSIXTime {getPOSIXTime = 1683391187999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qp77epd4gy5hrt8pnh6h73se4durwrrkes3u0vj6tycwsq7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7kyfpt\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[9] = 3a62eea8b81f1b880da67cd00ca85ad5aed39bccc2626c6abbcd1dcfea9a4f7e
#
# Funds at scholar 7's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 3a62eea8b81f1b880da67cd00ca85ad5aed39bccc2626c6abbcd1dcfea9a4f7e     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 8 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390863000},POSIXTime {getPOSIXTime = 1683391223999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390863000},POSIXTime {getPOSIXTime = 1683391223999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqau5f983jd4p5jxx7uxek4axcuuyqgc3q20d9el33ydg4kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqvdshe7\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[10] = 8a0f726c7cf9c953631ab96811b91c153e38282d625079a103798c431a919fa1
#
# Funds at scholar 8's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 8a0f726c7cf9c953631ab96811b91c153e38282d625079a103798c431a919fa1     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 9 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390908000},POSIXTime {getPOSIXTime = 1683391268999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390908000},POSIXTime {getPOSIXTime = 1683391268999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qry8r8w64h8t6luv4gcvny3snjzmytvrge5euj0ydqchh3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq8f955r\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[11] = f98cdc03887ae2558613e5a8a425c22fb33cf7106d3f6e15aae1218907ada43b
#
# Funds at scholar 9's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# f98cdc03887ae2558613e5a8a425c22fb33cf7106d3f6e15aae1218907ada43b     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 10 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390914000},POSIXTime {getPOSIXTime = 1683391274999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390914000},POSIXTime {getPOSIXTime = 1683391274999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzf7zduewu3zjw586mv8r0cxtctwsccsydk7d2hxdcad2s7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jql02nhc\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[12] = 9dbc77530bcc4479be37808e982eb20a3465ed63433e564c45e72afc079eacc7
#
# Funds at scholar 10's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 9dbc77530bcc4479be37808e982eb20a3465ed63433e564c45e72afc079eacc7     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 11 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390930000},POSIXTime {getPOSIXTime = 1683391290999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390930000},POSIXTime {getPOSIXTime = 1683391290999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qz5acr3p66e5jzts96jhlgh8nhuurydw5364xs9u2kdwlg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqrudtl4\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[13] = 24b2b8e2bb53a77ed764cd66a5e7016ba3430de18a3f76b10512da4b30f0e866
#
# Funds at scholar 11's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 24b2b8e2bb53a77ed764cd66a5e7016ba3430de18a3f76b10512da4b30f0e866     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 12 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390981000},POSIXTime {getPOSIXTime = 1683391341999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390981000},POSIXTime {getPOSIXTime = 1683391341999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qp85hggjkyjzq32m9hk6yfwp8xdz0j6kq7g8j4f2akfl9ckr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq8xh40m\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[14] = fcbaa4883d2a9ad0a53777e564e6925e618560a68703b8273a36cb8abde755b3
#
# Funds at scholar 12's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# fcbaa4883d2a9ad0a53777e564e6925e618560a68703b8273a36cb8abde755b3     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 13 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683390992000},POSIXTime {getPOSIXTime = 1683391352999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683390992000},POSIXTime {getPOSIXTime = 1683391352999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qp5uceg0yhxgra7a8emm0d4k8v6qqm4g3tg65ywtqkhcaawr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqyctq4d\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[15] = ebe32674cec92e89160cf81cae60d920bcaf4eea968639272c43530c3dc7eb7d
#
# Funds at scholar 13's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ebe32674cec92e89160cf81cae60d920bcaf4eea968639272c43530c3dc7eb7d     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 14 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391023000},POSIXTime {getPOSIXTime = 1683391383999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391023000},POSIXTime {getPOSIXTime = 1683391383999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqs5whf8xtzdn9myltr7svnug89g5hr48u4zl3lugcrxr67r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqruqfn5\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[16] = 9e2a660990cfba8a096b43c1d8a833f158808ae7c194b255e3505d3a21d7f81a
#
# Funds at scholar 14's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 9e2a660990cfba8a096b43c1d8a833f158808ae7c194b255e3505d3a21d7f81a     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 15 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391053000},POSIXTime {getPOSIXTime = 1683391413999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391053000},POSIXTime {getPOSIXTime = 1683391413999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qrj49qkfmr72mgmt3lsktde0havnv72yp9qsvsq6365dyp7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqnpl2rv\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[17] = 57e3c3d3e33e4599abd276ce2911dbe34798273e6d1fdd39b827b0e8f363f84e
#
# Funds at scholar 15's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 57e3c3d3e33e4599abd276ce2911dbe34798273e6d1fdd39b827b0e8f363f84e     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 16 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391074000},POSIXTime {getPOSIXTime = 1683391434999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391074000},POSIXTime {getPOSIXTime = 1683391434999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqgdvj84rncnlm754fwttn3py73hp85454tzxzll9sk98rkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqj6jhze\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[18] = 2390c75fc24cdbf68dbfbad0b834af1f1d6cb74b66da684aa4e11db9e8e9107c
#
# Funds at scholar 16's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 2390c75fc24cdbf68dbfbad0b834af1f1d6cb74b66da684aa4e11db9e8e9107c     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 17 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391095000},POSIXTime {getPOSIXTime = 1683391455999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391095000},POSIXTime {getPOSIXTime = 1683391455999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qrjk5w2t35r7qpuc0mlxcuazvta0e4d8wsn7mq6wpq4fa2kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq0zqdga\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[19] = 4e4344aefd8f9e8ccf1dd2d29303e33aaab264fe37b0f59e2db9a1deaa713283
#
# Funds at scholar 17's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 4e4344aefd8f9e8ccf1dd2d29303e33aaab264fe37b0f59e2db9a1deaa713283     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 18 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391111000},POSIXTime {getPOSIXTime = 1683391471999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391111000},POSIXTime {getPOSIXTime = 1683391471999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qrnartu48wqykfavssdsgsz6vvgqxgv9s43tgpzrauh6ugwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwu7lzs\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[20] = ef8f431cf4774a6fa579ca1da94d54b083c12594615531b096b03f48783dd9fb
#
# Funds at scholar 18's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ef8f431cf4774a6fa579ca1da94d54b083c12594615531b096b03f48783dd9fb     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 19 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391147000},POSIXTime {getPOSIXTime = 1683391507999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391147000},POSIXTime {getPOSIXTime = 1683391507999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpftg7deaxswzauukv2hqsegtrr4q680ayd6683k3rg8gkkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqv7jm9y\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[21] = f698c0666250f299e8e5b52d10250992acdcc005d08ed619047ae2be915bf7cc
#
# Funds at scholar 19's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# f698c0666250f299e8e5b52d10250992acdcc005d08ed619047ae2be915bf7cc     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 20 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391153000},POSIXTime {getPOSIXTime = 1683391513999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391153000},POSIXTime {getPOSIXTime = 1683391513999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzx9gsxhj09ne3vz73jzg25calq9skl3fxwedxdfu6y7gdkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqvt6lj0\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[22] = d9a8d0829b9cf68ef440ca4874faa4f2253c5c685e9954f3a1edeb61c061d2c2
#
# Funds at scholar 20's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# d9a8d0829b9cf68ef440ca4874faa4f2253c5c685e9954f3a1edeb61c061d2c2     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 21 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391173000},POSIXTime {getPOSIXTime = 1683391533999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391173000},POSIXTime {getPOSIXTime = 1683391533999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzlv9amdympgu47t6tu4ec5lz6uhu2qnq8ulwk9caasm7f7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqulv0pl\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[23] = 07e070b8759d1df9e7122fec51418223a0638e803886c3e152b26a447d817390
#
# Funds at scholar 21's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 07e070b8759d1df9e7122fec51418223a0638e803886c3e152b26a447d817390     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 22 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391189000},POSIXTime {getPOSIXTime = 1683391549999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391189000},POSIXTime {getPOSIXTime = 1683391549999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qq6nzgz24yj8u2fy45psnrn4emdwh7scjh29j43z3pv5rckr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7h6t4e\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[24] = c70abebf8fdb2802b85c74eee1b8a7cf358e57792c8ada0866a205cfcc8a977e
#
# Funds at scholar 22's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# c70abebf8fdb2802b85c74eee1b8a7cf358e57792c8ada0866a205cfcc8a977e     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 23 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391205000},POSIXTime {getPOSIXTime = 1683391565999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391205000},POSIXTime {getPOSIXTime = 1683391565999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qrhpp4kv5vxpr0kqerx5stkyfqghf8pjltmcucdscuzvg57r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkeka27\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[25] = f4fbd37f9c48cb4a5aa4e5cd7682e1268a56d4780fbba49e7a85668e233388d3
#
# Funds at scholar 23's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# f4fbd37f9c48cb4a5aa4e5cd7682e1268a56d4780fbba49e7a85668e233388d3     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 24 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391221000},POSIXTime {getPOSIXTime = 1683391581999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391221000},POSIXTime {getPOSIXTime = 1683391581999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzlweggfq6ara5tytufktkcyjv7j29garuhyufz5ryzxnqwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2lh7qe\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[26] = 8b2f06d3393604094a94b2ac75aa00f591ec8f8e20481bf90601ce1f7229d808
#
# Funds at scholar 24's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 8b2f06d3393604094a94b2ac75aa00f591ec8f8e20481bf90601ce1f7229d808     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 25 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391227000},POSIXTime {getPOSIXTime = 1683391587999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391227000},POSIXTime {getPOSIXTime = 1683391587999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qp0t92r5ep5suj08mpk8mcy7phfuq3607wmksp8z407z6kkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2xwugk\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[27] = 11707b7d7e05939b5ed7ce5b108e33dcc514b67b99f5fab1c98dc39b3ed8d5ec
#
# Funds at scholar 25's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 11707b7d7e05939b5ed7ce5b108e33dcc514b67b99f5fab1c98dc39b3ed8d5ec     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 26 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391238000},POSIXTime {getPOSIXTime = 1683391598999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391238000},POSIXTime {getPOSIXTime = 1683391598999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzhdl8anw4ssr75uguffuem6227ay9rh3wp855pq6scjc5xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqe2smw4\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[28] = 6b925bd58207522050d59c86279d6f4864ebb0329b9515197d9f6de0363d0f6e
#
# Funds at scholar 26's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 6b925bd58207522050d59c86279d6f4864ebb0329b9515197d9f6de0363d0f6e     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 27 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391243000},POSIXTime {getPOSIXTime = 1683391603999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391243000},POSIXTime {getPOSIXTime = 1683391603999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzg57krydk30ydzd39ltjvs9wqd3jsf2er5e8asr4faycfxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqmzupaz\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[29] = 68d53d3a691ebd80d9b6a1e20530935a1d0f41e4a13c53239d63f63339579cf6
#
# Funds at scholar 27's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 68d53d3a691ebd80d9b6a1e20530935a1d0f41e4a13c53239d63f63339579cf6     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 28 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391294000},POSIXTime {getPOSIXTime = 1683391654999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391294000},POSIXTime {getPOSIXTime = 1683391654999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpcfw8xjj9vk7889m45mpw4lnmt5ackful200xxp6q3r98wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqez5l32\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[30] = 79b78f57f92fbd3c2dc7ccaeba604b90a5c026fe69a8e041e723a46d0220a80b
#
# Funds at scholar 28's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 79b78f57f92fbd3c2dc7ccaeba604b90a5c026fe69a8e041e723a46d0220a80b     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 29 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391305000},POSIXTime {getPOSIXTime = 1683391665999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391305000},POSIXTime {getPOSIXTime = 1683391665999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzyp0dv2hq77jvhk4kh3y45g63tfx759ufwcsu892ukvegkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqqun809\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[31] = e0de5ffc476b1cbdebf5676b123c20a8ecd759ae00e0fe85391ebf25e9855c33
#
# Funds at scholar 29's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# e0de5ffc476b1cbdebf5676b123c20a8ecd759ae00e0fe85391ebf25e9855c33     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 30 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391346000},POSIXTime {getPOSIXTime = 1683391706999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391346000},POSIXTime {getPOSIXTime = 1683391706999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qp5g75sm5esea8alu07e8c5k63ywns5tq74lvh8ursr48s7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjpx5tl\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[32] = a829b513b9c6f41f3d43aadc2f8dd0a4031d85b992ef509f4855e26bd507fffd
#
# Funds at scholar 30's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# a829b513b9c6f41f3d43aadc2f8dd0a4031d85b992ef509f4855e26bd507fffd     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 31 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391357000},POSIXTime {getPOSIXTime = 1683391717999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391357000},POSIXTime {getPOSIXTime = 1683391717999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpy8fx7kasu376v3c9pskxckj5stk6ejy2nswnq0requ45kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqm0r9l6\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[33] = c07425cdc7da010449711caa8221f9e01cc949931e55f853409ed74403185236
#
# Funds at scholar 31's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# c07425cdc7da010449711caa8221f9e01cc949931e55f853409ed74403185236     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 32 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391428000},POSIXTime {getPOSIXTime = 1683391788999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391428000},POSIXTime {getPOSIXTime = 1683391788999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpazh38gxxnt6yxafz8vf0ryrdc8n8tyc4xlv97c7f8qqfwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5zqhdp\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[34] = 61ddce55e29fbe0c5246e381e92df04dc0182b677693d7e3e37d8070ebb57548
#
# Funds at scholar 32's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 61ddce55e29fbe0c5246e381e92df04dc0182b677693d7e3e37d8070ebb57548     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 33 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391444000},POSIXTime {getPOSIXTime = 1683391804999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391444000},POSIXTime {getPOSIXTime = 1683391804999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpf5pakhjntq8fyxmtc6gv6wf8c5dz8k9dv3nk06dk423awr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq4kdl8u\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[35] = 63e0e8f06f4d1fb6f79845672a65c52dfc56bf52ce3634aaf324a67329bef89d
#
# Funds at scholar 33's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 63e0e8f06f4d1fb6f79845672a65c52dfc56bf52ce3634aaf324a67329bef89d     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 34 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391505000},POSIXTime {getPOSIXTime = 1683391865999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391505000},POSIXTime {getPOSIXTime = 1683391865999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpfhfug63l0ys2a2vm0wldmxjjlaqgk4u280m4pmk6f8cp7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqpdfphd\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[36] = f1127e41dbc4bc7ca107143d20693000706ea6298d85b402842ca43e621e3c8f
#
# Funds at scholar 34's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# f1127e41dbc4bc7ca107143d20693000706ea6298d85b402842ca43e621e3c8f     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 35 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391526000},POSIXTime {getPOSIXTime = 1683391886999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391526000},POSIXTime {getPOSIXTime = 1683391886999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qrpjhy8rnc9h50vusd4tsh2nfep9w6n7qutdzs2gpjqfh6xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqffy4uy\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[37] = e95a6b1ee1f9d52fe607879c9ff0bd460fcfbece3e28bb3a703c504b7728cf4f
#
# Funds at scholar 35's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# e95a6b1ee1f9d52fe607879c9ff0bd460fcfbece3e28bb3a703c504b7728cf4f     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 36 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391536000},POSIXTime {getPOSIXTime = 1683391896999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391536000},POSIXTime {getPOSIXTime = 1683391896999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpdsderx7fdh3vx42sx8j4kjcxj3k2d58fgsd5ptya5ulywr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2ruk85\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[38] = cf7030fd4bf2247b609a8da8df7d78a6c0ab1a40f6224649d4794eff6fe7eddc
#
# Funds at scholar 36's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# cf7030fd4bf2247b609a8da8df7d78a6c0ab1a40f6224649d4794eff6fe7eddc     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 37 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391642000},POSIXTime {getPOSIXTime = 1683392002999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391642000},POSIXTime {getPOSIXTime = 1683392002999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qq4fsl04nuu03njzwh6n89uhgu63x9ypjeg84q4pdzvqttkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7ywduq\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[39] = 492799bab35022f9f304df841758c4752573786b1743407b3cc7fdbf5ffa585c
#
# Funds at scholar 37's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 492799bab35022f9f304df841758c4752573786b1743407b3cc7fdbf5ffa585c     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 38 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391683000},POSIXTime {getPOSIXTime = 1683392043999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391683000},POSIXTime {getPOSIXTime = 1683392043999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qq5gmdhh65mxm3pje855vwsgfrj90wye43grnq3zzu9ug0wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jql9ku83\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[40] = 703e5fadb708323e798568aa545f01b2841ad894576528ed84b7703a098c1c2f
#
# Funds at scholar 38's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 703e5fadb708323e798568aa545f01b2841ad894576528ed84b7703a098c1c2f     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 39 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391724000},POSIXTime {getPOSIXTime = 1683392084999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391724000},POSIXTime {getPOSIXTime = 1683392084999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpummduqr4zq3vkxmjxqwvatrfm2wgeefn23p3y5us2rxpkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqntpetu\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[41] = ad4eb0f66842c20b522dd269a6e95742bae5d2e66617cdd8a4dd62e04e0a029d
#
# Funds at scholar 39's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ad4eb0f66842c20b522dd269a6e95742bae5d2e66617cdd8a4dd62e04e0a029d     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 40 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391770000},POSIXTime {getPOSIXTime = 1683392130999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391770000},POSIXTime {getPOSIXTime = 1683392130999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzwxx7va22maycmt0wfhzw4q6zy885658swh3yzvxq5860wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqez9c58\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[42] = d8ac53a250abc19fee68dfe0ac1ec52a3f99a8be2c4f625f49b503a887f087f3
#
# Funds at scholar 40's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# d8ac53a250abc19fee68dfe0ac1ec52a3f99a8be2c4f625f49b503a887f087f3     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 41 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391801000},POSIXTime {getPOSIXTime = 1683392161999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391801000},POSIXTime {getPOSIXTime = 1683392161999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qp7sp0w8ljvmau95rsscmg8zegmem4cya6hmyr276hr3c7kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqpm58rl\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[43] = e1a4dc5f527923698000462170346f99af77026805a1435695d26470dfa76afb
#
# Funds at scholar 41's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# e1a4dc5f527923698000462170346f99af77026805a1435695d26470dfa76afb     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 42 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391806000},POSIXTime {getPOSIXTime = 1683392166999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391806000},POSIXTime {getPOSIXTime = 1683392166999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzwsqegmud7dcr8prnslmhh97war84dh4z9t7v5xgh8jh2xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqnq9x0k\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[44] = 7ab83a981834c9365f103dab5ac5a42f3e06d80932a62b79d6fc912d4ccaa966
#
# Funds at scholar 42's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 7ab83a981834c9365f103dab5ac5a42f3e06d80932a62b79d6fc912d4ccaa966     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 43 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391812000},POSIXTime {getPOSIXTime = 1683392172999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391812000},POSIXTime {getPOSIXTime = 1683392172999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qz2nmcnwdrxrksk4fvfw9x3myrxndcwhqwkxe5f9lw2azyxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqtxn85r\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[45] = af4bc13efed47f0284b7fa562eefd8a9786b630fa7474d5f6bdc7f74ad9a216b
#
# Funds at scholar 43's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# af4bc13efed47f0284b7fa562eefd8a9786b630fa7474d5f6bdc7f74ad9a216b     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 44 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391833000},POSIXTime {getPOSIXTime = 1683392193999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391833000},POSIXTime {getPOSIXTime = 1683392193999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpek6vrkj00g5vcvzxs74xrzt6clfwc964puu2k32f76hk7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqv26z8x\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[46] = 8e89dd167a44317af05c6c838b2eb083037e95090a3644933b649dce447970e9
#
# Funds at scholar 44's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 8e89dd167a44317af05c6c838b2eb083037e95090a3644933b649dce447970e9     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 45 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683391869000},POSIXTime {getPOSIXTime = 1683392229999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683391869000},POSIXTime {getPOSIXTime = 1683392229999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qq8ses7vgfl9rmj0tjtzvt3r7twpku4cv3c7naxtltlwwqwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq34fkvd\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[47] = 35ed0a7f9284f3f7cc2c694c1a5cc53daa3567d384b9ac751e1665256f183125
#
# Funds at scholar 45's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ...
#
# Funds at scholar 86's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# fb5a1cdc2779a3b1341552bca61ce6d7fc51c8d3960db696bc0ce8e5423a6dd1     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 87 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393067000},POSIXTime {getPOSIXTime = 1683393427999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393067000},POSIXTime {getPOSIXTime = 1683393427999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qprs6cc7p6xkuyedjrgg3w8g6r82jmvp8hq7zv8lhlshf07r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkplwl4\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[89] = d77129282c8dee76b7e6eae49cc404ed414b6a351c27bc2beaf8aadb09516286
#
# Funds at scholar 87's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# d77129282c8dee76b7e6eae49cc404ed414b6a351c27bc2beaf8aadb09516286     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 88 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393128000},POSIXTime {getPOSIXTime = 1683393488999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393128000},POSIXTime {getPOSIXTime = 1683393488999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qprks5kj24y2r2hdvav6rkdwef2m757epr54xnjc2tr398wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqla8ngy\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[90] = bab2544c2425c81c5d36e19e1329e6c00bbdc2d98947b13066f6565fb29bbf16
#
# Funds at scholar 88's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# bab2544c2425c81c5d36e19e1329e6c00bbdc2d98947b13066f6565fb29bbf16     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 89 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393224000},POSIXTime {getPOSIXTime = 1683393584999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393224000},POSIXTime {getPOSIXTime = 1683393584999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzz0xx5cz6su3kh6gldu7wzp2mhcffytwv0upg43hdkc0nxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqhw08as\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[91] = f6c5ad1e99777133af7b03ef9832769b1d727ecf10a33e5df38fd0925639a547
#
# Funds at scholar 89's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# f6c5ad1e99777133af7b03ef9832769b1d727ecf10a33e5df38fd0925639a547     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 90 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393270000},POSIXTime {getPOSIXTime = 1683393630999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393270000},POSIXTime {getPOSIXTime = 1683393630999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qrjwq07mqh4lhwamstx3gy69meqsvn7pylxtmhfadf7ut6kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqp6e7ud\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[92] = 3e4b2fd6a9a102cf613eeb6e9fcdc4e0ec0f0e812ca12e91b5db3607aef6c9a5
#
# Funds at scholar 90's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 3e4b2fd6a9a102cf613eeb6e9fcdc4e0ec0f0e812ca12e91b5db3607aef6c9a5     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 91 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393386000},POSIXTime {getPOSIXTime = 1683393746999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393386000},POSIXTime {getPOSIXTime = 1683393746999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qq6peyeak7ftpdwq7lgahssj4s5sslhcgcfd4wfgxtf52xkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwzhdsg\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[93] = 12f21b422b464a6db365abfd97b5c920a65090dc25d7b03e212ef4217fa4d594
#
# Funds at scholar 91's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 12f21b422b464a6db365abfd97b5c920a65090dc25d7b03e212ef4217fa4d594     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 92 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393442000},POSIXTime {getPOSIXTime = 1683393802999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393442000},POSIXTime {getPOSIXTime = 1683393802999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzmwzfavsycupvv35xjchq7w4q6yqxz67r5plrwglqsnve7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkktlxy\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[94] = d01c1a7e95c6a9ad07a8213e17808b330d6f1ae40e1a737cd2c5f204f004d529
#
# Funds at scholar 92's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# d01c1a7e95c6a9ad07a8213e17808b330d6f1ae40e1a737cd2c5f204f004d529     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 93 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393473000},POSIXTime {getPOSIXTime = 1683393833999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393473000},POSIXTime {getPOSIXTime = 1683393833999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzd3z04g5wlkgztjchdqkgg9j6hysmgk6xsgxf3m37glfl7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqnaeh54\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[95] = 9f3a6d2bcfbfbb338bb3a5b68369e0d2f439ef93018615349df41573a4bdd152
#
# Funds at scholar 93's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 9f3a6d2bcfbfbb338bb3a5b68369e0d2f439ef93018615349df41573a4bdd152     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 94 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393484000},POSIXTime {getPOSIXTime = 1683393844999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393484000},POSIXTime {getPOSIXTime = 1683393844999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqg3rrcvdvz2lrvayeakmt2ahlgv84y29ggjyhya7p80a67r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jquj2zsf\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[96] = ff7c2a0f810c66fa5aff77855fa49683f7350260d6e3ba316d52bbec430d601a
#
# Funds at scholar 94's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ff7c2a0f810c66fa5aff77855fa49683f7350260d6e3ba316d52bbec430d601a     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 95 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393504000},POSIXTime {getPOSIXTime = 1683393864999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393504000},POSIXTime {getPOSIXTime = 1683393864999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qq3k3mxh25zclz5hg95rzskf2k5m2z5qwr2ejcyant43evwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqqpmnnz\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[97] = 55bd4393e86e115d8b37fbe3213c678bfbb82b728864abebd238fb7386e4b991
#
# Funds at scholar 95's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 55bd4393e86e115d8b37fbe3213c678bfbb82b728864abebd238fb7386e4b991     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 96 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393580000},POSIXTime {getPOSIXTime = 1683393940999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393580000},POSIXTime {getPOSIXTime = 1683393940999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzeexmvhgklvm0sm5a93has8la8xzkalnghulxq07zs84q7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqadklvz\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[98] = 9fef4d9e22bbd22261e4b866a70244ac2af12c179ed3aa5613082913d4af0d42
#
# Funds at scholar 96's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 9fef4d9e22bbd22261e4b866a70244ac2af12c179ed3aa5613082913d4af0d42     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 97 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393591000},POSIXTime {getPOSIXTime = 1683393951999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393591000},POSIXTime {getPOSIXTime = 1683393951999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qz0djqvxvfg7xmpzr98jgmlzv870jg80qctaemrzhx7rx6kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqdqcucz\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[99] = 40345dd90be62afab73d1bbdc5bce26a2cc6385391e7e1d2ba10de72923b75fc
#
# Funds at scholar 97's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 40345dd90be62afab73d1bbdc5bce26a2cc6385391e7e1d2ba10de72923b75fc     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 98 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393607000},POSIXTime {getPOSIXTime = 1683393967999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393607000},POSIXTime {getPOSIXTime = 1683393967999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qpjsldudrtytstlgkfmy7z6dymu4yra9uperq2chmu9xaukr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq00l0a0\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[100] = 451c0ccdcdc8747699bcf6c94e9b3bc4cf8f9146ad9aab5587795166522c2579
#
# Funds at scholar 98's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 451c0ccdcdc8747699bcf6c94e9b3bc4cf8f9146ad9aab5587795166522c2579     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 99 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393628000},POSIXTime {getPOSIXTime = 1683393988999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393628000},POSIXTime {getPOSIXTime = 1683393988999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qzs2warxngdak4jdtmg0q7j2n3yc6gtrmhqwvq4gaq602lxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjxlpdl\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[101] = dee428a65e529af5248e04c870a23cd4c3c2bc785c576b635d137a7690074c0d
#
# Funds at scholar 99's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# dee428a65e529af5248e04c870a23cd4c3c2bc785c576b635d137a7690074c0d     1        400000000 lovelace + TxOutDatumNone
#
# ----- Contract 100 -----
#
# Rounding  `TransactionInput` txInterval boundries to:(POSIXTime {getPOSIXTime = 1683393663000},POSIXTime {getPOSIXTime = 1683394023999})
# TransactionInput {txInterval = (POSIXTime {getPOSIXTime = 1683393663000},POSIXTime {getPOSIXTime = 1683394023999}), txInputs = [NormalInput (IChoice (ChoiceId "Pay Scholarship" "\"addr_test1vq08ewa9gw55z4wfd8fqexgkm8eyukm93qa2vr4w2u22j2g6ktqxw\"") 0)]}
# Payment 1
#   Acccount: "\"addr_test1zq6zvzptxvhdhd2392qe30ar9htwgczyg5802he0luk2w3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqlk60k0\""
#   Payee: Party "\"addr_test1qqtdfkwpjq7amgjvka4czt7cqvxa4zhe3jmaa8jaqpjxfhkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq6hmtxv\""
#   Ada: Lovelace {getLovelace = 400000000}
# TX[102] = 1d8b4dd0b5b14cb19bf24800de5912a43cbace721c62935bdf47cff161324ef0
#
# Funds at scholar 100's address:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 1d8b4dd0b5b14cb19bf24800de5912a43cbace721c62935bdf47cff161324ef0     1        400000000 lovelace + TxOutDatumNone

# %% [markdown]
# ## Cleanup
#
# Return the funds to the administrator.

# %%
cardano-cli transaction build \
  --testnet-magic "$CARDANO_TESTNET_MAGIC" \
  --babbage-era \
  $(for i in $(seq 1 2); do echo "--tx-in ${TX[$((i+2))]}#1 --tx-in-script-file multisig.json"; done) \
  $(for i in $(seq 3 $NUMBER_OF_SCHOLARSHIPS); do echo "--tx-in ${TX[$((i+2))]}#1"; done) \
  --change-address "$ADMINISTRATOR_ADDR" \
  --witness-override $((2 + NUMBER_OF_SCHOLARSHIPS)) \
  --out-file txs/cleanup.unsigned
# Out:
# Estimated transaction fee: Lovelace 774241

# %%
/extra/iohk/bin/marlowe-cli transaction submit \
  --tx-body-file txs/cleanup.unsigned \
  --required-signer "$ADMINISTRATOR_SKEY" \
  --required-signer "$TREASURER_1_SKEY" \
  --required-signer "$TREASURER_2_SKEY" \
  --required-signer "$TREASURER_3_SKEY" \
  $(for i in $(seq 3 $NUMBER_OF_SCHOLARSHIPS); do echo "--required-signer ${SCHOLAR_SKEY[$i]}"; done) \
  --timeout 600
# Out:
# TxId "63e5ebbc58b84bc441d67dbc484c8f5425b5a1b25011ae04ed3ba76f9ad40e00"

# %%
cardano-cli query utxo --testnet-magic "$CARDANO_TESTNET_MAGIC" --address "$TREASURY_ADDR"
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------

# %%
cardano-cli query utxo \
  --testnet-magic "$CARDANO_TESTNET_MAGIC" \
  $(for i in $(seq 1 $NUMBER_OF_SCHOLARSHIPS); do echo "--address ${SCHOLAR_ADDR[$i]}"; done)
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
